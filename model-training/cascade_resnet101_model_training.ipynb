# %% [markdown]
# <a href="https://colab.research.google.com/github/NamishBansal15/substation-detection/blob/main/model-training/cascade_resnet101_model_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.chdir('/content')

# !python -m pip install -q 'git+https://github.com/facebookresearch/detectron2.git'
# !pip install -q roboflow
import detectron2
import roboflow
print(f'Detectron2: {detectron2.__version__}')
print('Roboflow installed.')
print('All dependencies ready.')
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.5/155.5 kB 16.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 59.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.8/269.8 kB 28.2 MB/s eta 0:00:00
#   Building wheel for detectron2 (setup.py) ... done
#   Building wheel for fvcore (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.3/260.3 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 82.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 141.3 MB/s eta 0:00:00
# Detectron2: 0.6
# Roboflow installed.
# All dependencies ready.

# %%
# ═══════════════════════════════════════════════════════════════════════════
# CASCADE R-CNN RESNET-101 FPN — COMPLETE PIPELINE IN ONE CELL
# Saves directly to Drive during training so disconnects can't lose progress
# ═══════════════════════════════════════════════════════════════════════════

import os, json, glob, getpass, csv
from google.colab import drive
from roboflow import Roboflow
from detectron2 import model_zoo
from detectron2.config import get_cfg
from detectron2.data.datasets import register_coco_instances
from detectron2.data import MetadataCatalog, DatasetCatalog, build_detection_test_loader
from detectron2.engine import DefaultTrainer, DefaultPredictor
from detectron2.evaluation import COCOEvaluator, inference_on_dataset

# ── 1. Mount Drive ────────────────────────────────────────────────────────
drive.mount('/content/drive')
DRIVE_OUTPUT_DIR = '/content/drive/MyDrive/Cascade_RCNN/ResNet101'
os.makedirs(DRIVE_OUTPUT_DIR, exist_ok=True)

# ── 2. Download dataset from Roboflow ─────────────────────────────────────
RF_API_KEY   = getpass.getpass('Roboflow API Key: ')
RF_WORKSPACE = input('Workspace name: ').strip()
RF_PROJECT   = input('Project name: ').strip()
RF_VERSION   = int(input('Version number: ').strip())

rf = Roboflow(api_key=RF_API_KEY)
project = rf.workspace(RF_WORKSPACE).project(RF_PROJECT)
version = project.version(RF_VERSION)
dataset = version.download('coco', location='/content/dataset')
DATASET_ROOT = '/content/dataset'

# ── 3. Verify dataset + detect classes ────────────────────────────────────
TRAIN_DIR = f'{DATASET_ROOT}/train'
VALID_DIR = f'{DATASET_ROOT}/valid'
TEST_DIR  = f'{DATASET_ROOT}/test'

def find_ann(split_dir):
    for fname in ['_annotations.coco.json', 'annotations.json']:
        path = f'{split_dir}/{fname}'
        if os.path.exists(path):
            return path
    raise FileNotFoundError(f'No annotation file in {split_dir}')

TRAIN_ANN = find_ann(TRAIN_DIR)
VALID_ANN = find_ann(VALID_DIR)
TEST_ANN  = find_ann(TEST_DIR)

with open(TRAIN_ANN) as f:
    coco_data = json.load(f)
CLASSES = [cat['name'] for cat in sorted(coco_data['categories'], key=lambda x: x['id'])]
NUM_CLASSES = len(CLASSES)
print(f'Classes ({NUM_CLASSES}): {CLASSES}')

# ── 4. Register datasets ──────────────────────────────────────────────────
for split in ['train', 'valid', 'test']:
    name = f'substation_{split}'
    if name in DatasetCatalog:
        DatasetCatalog.remove(name)
        MetadataCatalog.remove(name)

register_coco_instances('substation_train', {}, TRAIN_ANN, TRAIN_DIR)
register_coco_instances('substation_valid', {}, VALID_ANN, VALID_DIR)
register_coco_instances('substation_test',  {}, TEST_ANN,  TEST_DIR)
for split in ['train', 'valid', 'test']:
    MetadataCatalog.get(f'substation_{split}').thing_classes = CLASSES

# ── 5. Configure Cascade R-CNN ResNet-101 FPN ─────────────────────────────
cfg = get_cfg()

# Use ResNet-50 base config then swap backbone depth to 101
cfg.merge_from_file(model_zoo.get_config_file('Misc/cascade_mask_rcnn_R_50_FPN_3x.yaml'))
cfg.MODEL.RESNETS.DEPTH = 101
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url('Misc/cascade_mask_rcnn_R_50_FPN_3x.yaml')

cfg.DATASETS.TRAIN = ('substation_train',)
cfg.DATASETS.TEST  = ('substation_valid',)
cfg.DATALOADER.NUM_WORKERS = 2

cfg.SOLVER.IMS_PER_BATCH     = 4
cfg.SOLVER.BASE_LR           = 0.001
cfg.SOLVER.WARMUP_FACTOR     = 0.001
cfg.SOLVER.MAX_ITER          = 13000
cfg.SOLVER.STEPS             = (9000, 12000)
cfg.SOLVER.GAMMA             = 0.1
cfg.SOLVER.CHECKPOINT_PERIOD = 500
cfg.SOLVER.WARMUP_ITERS      = 500
cfg.TEST.EVAL_PERIOD         = 500

cfg.MODEL.ROI_HEADS.NUM_CLASSES = NUM_CLASSES
cfg.MODEL.MASK_ON = False

cfg.INPUT.MIN_SIZE_TRAIN = (640,)
cfg.INPUT.MAX_SIZE_TRAIN = 640
cfg.INPUT.MIN_SIZE_TEST  = 640
cfg.INPUT.MAX_SIZE_TEST  = 640

cfg.OUTPUT_DIR = f'{DRIVE_OUTPUT_DIR}/output'
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

print(f'Output saving directly to Drive: {cfg.OUTPUT_DIR}')
print(f'Backbone: ResNet-101')
print(f'Max iterations: {cfg.SOLVER.MAX_ITER} (~50 epochs)')

# ── 6. Train ──────────────────────────────────────────────────────────────
class TrainerWithEval(DefaultTrainer):
    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            output_folder = os.path.join(cfg.OUTPUT_DIR, 'eval')
        return COCOEvaluator(dataset_name, cfg, False, output_folder)

trainer = TrainerWithEval(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
print('Training complete.')

# ── 7. Load best checkpoint ───────────────────────────────────────────────
ckpts = sorted(glob.glob(f'{cfg.OUTPUT_DIR}/model_*.pth'))
BEST_CKPT = ckpts[-1] if ckpts else os.path.join(cfg.OUTPUT_DIR, 'model_final.pth')
print(f'Using checkpoint: {BEST_CKPT}')

cfg.MODEL.WEIGHTS = BEST_CKPT
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.3
predictor = DefaultPredictor(cfg)

# ── 8. Evaluate on validation set ─────────────────────────────────────────
print('\n=== Validation Set ===')
val_evaluator = COCOEvaluator('substation_valid', cfg, False, output_dir=f'{cfg.OUTPUT_DIR}/eval_valid')
val_loader = build_detection_test_loader(cfg, 'substation_valid')
val_results = inference_on_dataset(predictor.model, val_loader, val_evaluator)
print(val_results)

# ── 9. Evaluate on test set ───────────────────────────────────────────────
print('\n=== Test Set ===')
test_evaluator = COCOEvaluator('substation_test', cfg, False, output_dir=f'{cfg.OUTPUT_DIR}/eval_test')
test_loader = build_detection_test_loader(cfg, 'substation_test')
test_results = inference_on_dataset(predictor.model, test_loader, test_evaluator)
print(test_results)

# ── 10. Summary table + chart stats ──────────────────────────────────────
MODEL_NAME = 'Cascade R-CNN ResNet-101 FPN'

val_ap50  = val_results['bbox'].get('AP50')
val_ap    = val_results['bbox'].get('AP')
test_ap50 = test_results['bbox'].get('AP50')
test_ap   = test_results['bbox'].get('AP')

per_class = {}
for k, v in test_results['bbox'].items():
    if k.startswith('AP-'):
        per_class[k.replace('AP-', '')] = v

target_classes = ['Alt Energy', 'Circuit Breaker', 'Control', 'Power Lines', 'Reactor', 'Transformer']
panel_labels   = ['(c)', '(d)', '(e)', '(f)', '(g)', '(h)']

print('\n' + '=' * 65)
print(f'  FINAL RESULTS — {MODEL_NAME}')
print('=' * 65)
print(f'\n(a) Overall Performance (mAP@50):')
print(f'    Validation : {val_ap50:.2f}')
print(f'    Test       : {test_ap50:.2f}')
print(f'\n(b) Overall Performance (mAP@50:95):')
print(f'    Validation : {val_ap:.2f}')
print(f'    Test       : {test_ap:.2f}')
print()
for label, cls in zip(panel_labels, target_classes):
    val = per_class.get(cls, float('nan'))
    print(f'{label} {cls} (AP test): {val:.2f}')

print('=' * 65)

# ── 11. Save CSV to Drive ─────────────────────────────────────────────────
csv_path = f'{DRIVE_OUTPUT_DIR}/results_for_charts.csv'
rows = [
    ['Metric', 'Validation', 'Test'],
    ['mAP@50 Overall',    f'{val_ap50:.2f}',  f'{test_ap50:.2f}'],
    ['mAP@50:95 Overall', f'{val_ap:.2f}',    f'{test_ap:.2f}'],
]
for cls in target_classes:
    v = per_class.get(cls, float('nan'))
    rows.append([f'AP - {cls}', 'N/A', f'{v:.2f}'])

with open(csv_path, 'w', newline='') as f:
    csv.writer(f).writerows(rows)

print(f'\nCSV saved to: {csv_path}')
print(f'Checkpoint saved at: {BEST_CKPT}')
print('Everything saved directly to Google Drive.')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Roboflow API Key: ··········
# Workspace name: space-weather
# Project name: merged-dataset-gzbkg
# Version number: 1
# loading Roboflow workspace...
# loading Roboflow project...
# Classes (7): ['components', 'Alt Energy', 'Circuit Breaker', 'Control', 'Power Lines', 'Reactor', 'Transformer']
# Output saving directly to Drive: /content/drive/MyDrive/Cascade_RCNN/ResNet101/output
# Backbone: ResNet-101
# Max iterations: 13000 (~50 epochs)
# [07/05 23:33:22 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): CascadeROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): ModuleList(
#       (0-2): 3 x FastRCNNConvFCHead(
#         (flatten): Flatten(start_dim=1, end_dim=-1)
#         (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#         (fc_relu1): ReLU()
#         (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#         (fc_relu2): ReLU()
#       )
#     )
#     (box_predictor): ModuleList(
#       (0-2): 3 x FastRCNNOutputLayers(
#         (cls_score): Linear(in_features=1024, out_features=8, bias=True)
#         (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#       )
#     )
#   )
# )
# WARNING [07/05 23:33:22 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/05 23:33:22 d2.data.datasets.coco]: Loaded 1042 images in COCO format from /content/dataset/train/_annotations.coco.json
# [07/05 23:33:22 d2.data.build]: Removed 1 images with no usable annotations. 1041 images left.
# [07/05 23:33:22 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640,), max_size=640, sample_style='choice'), RandomFlip()]
# [07/05 23:33:22 d2.data.build]: Using training sampler TrainingSampler
# [07/05 23:33:22 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/05 23:33:22 d2.data.common]: Serializing 1041 elements to byte tensors and concatenating them all ...
# [07/05 23:33:23 d2.data.common]: Serialized dataset takes 0.34 MiB
# [07/05 23:33:23 d2.data.build]: Making batched data loader with batch_size=4
# [07/05 23:33:23 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/Misc/cascade_mask_rcnn_R_50_FPN_3x/144998488/model_final_480dd8.pkl ...
# model_final_480dd8.pkl: 288MB [00:01, 172MB/s]
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.0.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (8, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.0.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (8,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.1.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (8, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.1.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (8,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.2.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (8, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.2.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (8,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# backbone.bottom_up.res4.10.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.10.conv1.weight
# backbone.bottom_up.res4.10.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.10.conv2.weight
# backbone.bottom_up.res4.10.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.10.conv3.weight
# backbone.bottom_up.res4.11.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.11.conv1.weight
# backbone.bottom_up.res4.11.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.11.conv2.weight
# backbone.bottom_up.res4.11.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.11.conv3.weight
# backbone.bottom_up.res4.12.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.12.conv1.weight
# backbone.bottom_up.res4.12.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.12.conv2.weight
# backbone.bottom_up.res4.12.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.12.conv3.weight
# backbone.bottom_up.res4.13.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.13.conv1.weight
# backbone.bottom_up.res4.13.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.13.conv2.weight
# backbone.bottom_up.res4.13.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.13.conv3.weight
# backbone.bottom_up.res4.14.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.14.conv1.weight
# backbone.bottom_up.res4.14.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.14.conv2.weight
# backbone.bottom_up.res4.14.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.14.conv3.weight
# backbone.bottom_up.res4.15.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.15.conv1.weight
# backbone.bottom_up.res4.15.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.15.conv2.weight
# backbone.bottom_up.res4.15.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.15.conv3.weight
# backbone.bottom_up.res4.16.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.16.conv1.weight
# backbone.bottom_up.res4.16.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.16.conv2.weight
# backbone.bottom_up.res4.16.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.16.conv3.weight
# backbone.bottom_up.res4.17.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.17.conv1.weight
# backbone.bottom_up.res4.17.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.17.conv2.weight
# backbone.bottom_up.res4.17.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.17.conv3.weight
# backbone.bottom_up.res4.18.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.18.conv1.weight
# backbone.bottom_up.res4.18.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.18.conv2.weight
# backbone.bottom_up.res4.18.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.18.conv3.weight
# backbone.bottom_up.res4.19.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.19.conv1.weight
# backbone.bottom_up.res4.19.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.19.conv2.weight
# backbone.bottom_up.res4.19.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.19.conv3.weight
# backbone.bottom_up.res4.20.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.20.conv1.weight
# backbone.bottom_up.res4.20.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.20.conv2.weight
# backbone.bottom_up.res4.20.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.20.conv3.weight
# backbone.bottom_up.res4.21.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.21.conv1.weight
# backbone.bottom_up.res4.21.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.21.conv2.weight
# backbone.bottom_up.res4.21.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.21.conv3.weight
# backbone.bottom_up.res4.22.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.22.conv1.weight
# backbone.bottom_up.res4.22.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.22.conv2.weight
# backbone.bottom_up.res4.22.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.22.conv3.weight
# backbone.bottom_up.res4.6.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.6.conv1.weight
# backbone.bottom_up.res4.6.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.6.conv2.weight
# backbone.bottom_up.res4.6.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.6.conv3.weight
# backbone.bottom_up.res4.7.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.7.conv1.weight
# backbone.bottom_up.res4.7.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.7.conv2.weight
# backbone.bottom_up.res4.7.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.7.conv3.weight
# backbone.bottom_up.res4.8.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.8.conv1.weight
# backbone.bottom_up.res4.8.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.8.conv2.weight
# backbone.bottom_up.res4.8.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.8.conv3.weight
# backbone.bottom_up.res4.9.conv1.norm.{bias, weight}
# backbone.bottom_up.res4.9.conv1.weight
# backbone.bottom_up.res4.9.conv2.norm.{bias, weight}
# backbone.bottom_up.res4.9.conv2.weight
# backbone.bottom_up.res4.9.conv3.norm.{bias, weight}
# backbone.bottom_up.res4.9.conv3.weight
# roi_heads.box_predictor.0.cls_score.{bias, weight}
# roi_heads.box_predictor.1.cls_score.{bias, weight}
# roi_heads.box_predictor.2.cls_score.{bias, weight}
# WARNING:fvcore.common.checkpoint:The checkpoint state_dict contains keys that are not used by the model:
#   roi_heads.mask_head.mask_fcn1.{bias, weight}
#   roi_heads.mask_head.mask_fcn2.{bias, weight}
#   roi_heads.mask_head.mask_fcn3.{bias, weight}
#   roi_heads.mask_head.mask_fcn4.{bias, weight}
#   roi_heads.mask_head.deconv.{bias, weight}
#   roi_heads.mask_head.predictor.{bias, weight}
# [07/05 23:33:25 d2.engine.train_loop]: Starting training from iteration 0
# torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4381.)
# W0705 23:33:28.134000 8185 torch/fx/_symbolic_trace.py:53] is_fx_tracing will return true for both fx.symbolic_trace and torch.export. Please use is_fx_tracing_symbolic_tracing() for specifically fx.symbolic_trace or torch.compiler.is_compiling() for specifically torch.export/compile.
# [07/05 23:33:45 d2.utils.events]:  eta: 2:55:06  iter: 19  total_loss: 31.46  loss_cls_stage0: 4.001  loss_box_reg_stage0: 1.645  loss_cls_stage1: 0  loss_box_reg_stage1: 0  loss_cls_stage2: 0  loss_box_reg_stage2: 0  loss_rpn_cls: 14.51  loss_rpn_loc: 2.701    time: 0.8370  last_time: 1.0346  data_time: 0.0450  last_data_time: 0.0227   lr: 3.8962e-05  max_mem: 3583M
# [07/05 23:34:09 d2.utils.events]:  eta: 3:19:32  iter: 39  total_loss: 3.234  loss_cls_stage0: 0.1376  loss_box_reg_stage0: 0.05956  loss_cls_stage1: 0.3853  loss_box_reg_stage1: 0.04872  loss_cls_stage2: 0.09483  loss_box_reg_stage2: 0.009114  loss_rpn_cls: 1.29  loss_rpn_loc: 0.707    time: 0.9346  last_time: 0.9799  data_time: 0.0327  last_data_time: 0.0292   lr: 7.8922e-05  max_mem: 3583M
# [07/05 23:34:30 d2.utils.events]:  eta: 3:35:09  iter: 59  total_loss: 0.7984  loss_cls_stage0: 0.09625  loss_box_reg_stage0: 0.04856  loss_cls_stage1: 0.1056  loss_box_reg_stage1: 0.03061  loss_cls_stage2: 0.09889  loss_box_reg_stage2: 0.02176  loss_rpn_cls: 0.2694  loss_rpn_loc: 0.09342    time: 0.9716  last_time: 1.0767  data_time: 0.0303  last_data_time: 0.0228   lr: 0.00011888  max_mem: 3583M
# [07/05 23:34:52 d2.utils.events]:  eta: 3:44:17  iter: 79  total_loss: 0.5106  loss_cls_stage0: 0.1128  loss_box_reg_stage0: 0.04434  loss_cls_stage1: 0.05974  loss_box_reg_stage1: 0.02868  loss_cls_stage2: 0.0417  loss_box_reg_stage2: 0.01399  loss_rpn_cls: 0.1386  loss_rpn_loc: 0.06001    time: 1.0066  last_time: 1.1324  data_time: 0.0258  last_data_time: 0.0112   lr: 0.00015884  max_mem: 3583M
# [07/05 23:35:15 d2.utils.events]:  eta: 3:49:31  iter: 99  total_loss: 0.5908  loss_cls_stage0: 0.1127  loss_box_reg_stage0: 0.06042  loss_cls_stage1: 0.05628  loss_box_reg_stage1: 0.02073  loss_cls_stage2: 0.05079  loss_box_reg_stage2: 0.01345  loss_rpn_cls: 0.1265  loss_rpn_loc: 0.07941    time: 1.0315  last_time: 1.0625  data_time: 0.0222  last_data_time: 0.0311   lr: 0.0001988  max_mem: 3583M
# [07/05 23:35:36 d2.utils.events]:  eta: 3:49:09  iter: 119  total_loss: 0.5015  loss_cls_stage0: 0.09757  loss_box_reg_stage0: 0.04333  loss_cls_stage1: 0.05884  loss_box_reg_stage1: 0.02066  loss_cls_stage2: 0.04532  loss_box_reg_stage2: 0.01158  loss_rpn_cls: 0.1312  loss_rpn_loc: 0.05811    time: 1.0406  last_time: 1.0597  data_time: 0.0279  last_data_time: 0.0256   lr: 0.00023876  max_mem: 3583M
# [07/05 23:35:58 d2.utils.events]:  eta: 3:48:48  iter: 139  total_loss: 0.5816  loss_cls_stage0: 0.1144  loss_box_reg_stage0: 0.0547  loss_cls_stage1: 0.07471  loss_box_reg_stage1: 0.02504  loss_cls_stage2: 0.05656  loss_box_reg_stage2: 0.01239  loss_rpn_cls: 0.1163  loss_rpn_loc: 0.04537    time: 1.0469  last_time: 1.0303  data_time: 0.0279  last_data_time: 0.0424   lr: 0.00027872  max_mem: 3583M
# [07/05 23:36:19 d2.utils.events]:  eta: 3:47:54  iter: 159  total_loss: 0.498  loss_cls_stage0: 0.113  loss_box_reg_stage0: 0.07  loss_cls_stage1: 0.06115  loss_box_reg_stage1: 0.02869  loss_cls_stage2: 0.04615  loss_box_reg_stage2: 0.01269  loss_rpn_cls: 0.1338  loss_rpn_loc: 0.04214    time: 1.0472  last_time: 1.0500  data_time: 0.0252  last_data_time: 0.0216   lr: 0.00031868  max_mem: 3583M
# [07/05 23:36:40 d2.utils.events]:  eta: 3:45:22  iter: 179  total_loss: 0.5112  loss_cls_stage0: 0.1343  loss_box_reg_stage0: 0.0676  loss_cls_stage1: 0.07023  loss_box_reg_stage1: 0.03116  loss_cls_stage2: 0.05069  loss_box_reg_stage2: 0.0168  loss_rpn_cls: 0.09197  loss_rpn_loc: 0.03163    time: 1.0448  last_time: 1.0314  data_time: 0.0273  last_data_time: 0.0105   lr: 0.00035864  max_mem: 3583M
# [07/05 23:37:00 d2.utils.events]:  eta: 3:43:59  iter: 199  total_loss: 0.7306  loss_cls_stage0: 0.1892  loss_box_reg_stage0: 0.08305  loss_cls_stage1: 0.1135  loss_box_reg_stage1: 0.05221  loss_cls_stage2: 0.07164  loss_box_reg_stage2: 0.02405  loss_rpn_cls: 0.1003  loss_rpn_loc: 0.04906    time: 1.0420  last_time: 0.9782  data_time: 0.0257  last_data_time: 0.0268   lr: 0.0003986  max_mem: 3583M
# [07/05 23:37:21 d2.utils.events]:  eta: 3:43:01  iter: 219  total_loss: 0.5182  loss_cls_stage0: 0.1587  loss_box_reg_stage0: 0.08292  loss_cls_stage1: 0.07178  loss_box_reg_stage1: 0.04011  loss_cls_stage2: 0.04303  loss_box_reg_stage2: 0.01615  loss_rpn_cls: 0.09485  loss_rpn_loc: 0.02205    time: 1.0421  last_time: 1.0132  data_time: 0.0276  last_data_time: 0.0279   lr: 0.00043856  max_mem: 3583M
# [07/05 23:37:41 d2.utils.events]:  eta: 3:41:07  iter: 239  total_loss: 0.6317  loss_cls_stage0: 0.1942  loss_box_reg_stage0: 0.1176  loss_cls_stage1: 0.08602  loss_box_reg_stage1: 0.05385  loss_cls_stage2: 0.04326  loss_box_reg_stage2: 0.02157  loss_rpn_cls: 0.07609  loss_rpn_loc: 0.02217    time: 1.0406  last_time: 1.0145  data_time: 0.0289  last_data_time: 0.0298   lr: 0.00047852  max_mem: 3583M
# [07/05 23:38:02 d2.utils.events]:  eta: 3:40:16  iter: 259  total_loss: 0.5859  loss_cls_stage0: 0.1648  loss_box_reg_stage0: 0.1095  loss_cls_stage1: 0.0922  loss_box_reg_stage1: 0.06367  loss_cls_stage2: 0.05198  loss_box_reg_stage2: 0.01973  loss_rpn_cls: 0.06345  loss_rpn_loc: 0.01934    time: 1.0396  last_time: 1.0042  data_time: 0.0261  last_data_time: 0.0218   lr: 0.00051848  max_mem: 3583M
# [07/05 23:38:22 d2.utils.events]:  eta: 3:39:16  iter: 279  total_loss: 0.6348  loss_cls_stage0: 0.2002  loss_box_reg_stage0: 0.1069  loss_cls_stage1: 0.0955  loss_box_reg_stage1: 0.06605  loss_cls_stage2: 0.05028  loss_box_reg_stage2: 0.02211  loss_rpn_cls: 0.0701  loss_rpn_loc: 0.02172    time: 1.0382  last_time: 1.0368  data_time: 0.0231  last_data_time: 0.0113   lr: 0.00055844  max_mem: 3583M
# [07/05 23:38:43 d2.utils.events]:  eta: 3:38:34  iter: 299  total_loss: 0.5196  loss_cls_stage0: 0.15  loss_box_reg_stage0: 0.1041  loss_cls_stage1: 0.0709  loss_box_reg_stage1: 0.05097  loss_cls_stage2: 0.03722  loss_box_reg_stage2: 0.01773  loss_rpn_cls: 0.04856  loss_rpn_loc: 0.01959    time: 1.0371  last_time: 0.9884  data_time: 0.0253  last_data_time: 0.0278   lr: 0.0005984  max_mem: 3584M
# [07/05 23:39:03 d2.utils.events]:  eta: 3:38:13  iter: 319  total_loss: 0.5344  loss_cls_stage0: 0.1458  loss_box_reg_stage0: 0.07569  loss_cls_stage1: 0.07672  loss_box_reg_stage1: 0.04033  loss_cls_stage2: 0.05933  loss_box_reg_stage2: 0.01393  loss_rpn_cls: 0.09116  loss_rpn_loc: 0.02937    time: 1.0362  last_time: 1.0979  data_time: 0.0299  last_data_time: 0.0541   lr: 0.00063836  max_mem: 3584M
# [07/05 23:39:24 d2.utils.events]:  eta: 3:37:53  iter: 339  total_loss: 0.6369  loss_cls_stage0: 0.1844  loss_box_reg_stage0: 0.09575  loss_cls_stage1: 0.08555  loss_box_reg_stage1: 0.05595  loss_cls_stage2: 0.05434  loss_box_reg_stage2: 0.01883  loss_rpn_cls: 0.1337  loss_rpn_loc: 0.03193    time: 1.0362  last_time: 1.0344  data_time: 0.0284  last_data_time: 0.0352   lr: 0.00067832  max_mem: 3584M
# [07/05 23:39:45 d2.utils.events]:  eta: 3:37:48  iter: 359  total_loss: 0.6964  loss_cls_stage0: 0.2144  loss_box_reg_stage0: 0.1192  loss_cls_stage1: 0.1016  loss_box_reg_stage1: 0.06572  loss_cls_stage2: 0.06433  loss_box_reg_stage2: 0.02507  loss_rpn_cls: 0.07164  loss_rpn_loc: 0.02023    time: 1.0367  last_time: 1.0509  data_time: 0.0270  last_data_time: 0.0386   lr: 0.00071828  max_mem: 3584M
# [07/05 23:40:06 d2.utils.events]:  eta: 3:37:38  iter: 379  total_loss: 0.5478  loss_cls_stage0: 0.1784  loss_box_reg_stage0: 0.1047  loss_cls_stage1: 0.08378  loss_box_reg_stage1: 0.05557  loss_cls_stage2: 0.04432  loss_box_reg_stage2: 0.01937  loss_rpn_cls: 0.0546  loss_rpn_loc: 0.02149    time: 1.0371  last_time: 1.0142  data_time: 0.0246  last_data_time: 0.0264   lr: 0.00075824  max_mem: 3584M
# [07/05 23:40:26 d2.utils.events]:  eta: 3:37:14  iter: 399  total_loss: 0.7293  loss_cls_stage0: 0.2259  loss_box_reg_stage0: 0.1397  loss_cls_stage1: 0.1183  loss_box_reg_stage1: 0.08756  loss_cls_stage2: 0.05422  loss_box_reg_stage2: 0.02458  loss_rpn_cls: 0.07007  loss_rpn_loc: 0.02109    time: 1.0369  last_time: 1.0225  data_time: 0.0250  last_data_time: 0.0244   lr: 0.0007982  max_mem: 3584M
# [07/05 23:40:47 d2.utils.events]:  eta: 3:36:57  iter: 419  total_loss: 0.6401  loss_cls_stage0: 0.1783  loss_box_reg_stage0: 0.1264  loss_cls_stage1: 0.1035  loss_box_reg_stage1: 0.08125  loss_cls_stage2: 0.04864  loss_box_reg_stage2: 0.02539  loss_rpn_cls: 0.06722  loss_rpn_loc: 0.01987    time: 1.0371  last_time: 1.0099  data_time: 0.0262  last_data_time: 0.0238   lr: 0.00083816  max_mem: 3584M
# [07/05 23:41:08 d2.utils.events]:  eta: 3:36:34  iter: 439  total_loss: 0.5982  loss_cls_stage0: 0.1332  loss_box_reg_stage0: 0.09692  loss_cls_stage1: 0.08106  loss_box_reg_stage1: 0.06167  loss_cls_stage2: 0.04778  loss_box_reg_stage2: 0.01945  loss_rpn_cls: 0.1037  loss_rpn_loc: 0.03291    time: 1.0365  last_time: 1.0431  data_time: 0.0294  last_data_time: 0.0410   lr: 0.00087812  max_mem: 3584M
# [07/05 23:41:29 d2.utils.events]:  eta: 3:36:11  iter: 459  total_loss: 0.6741  loss_cls_stage0: 0.1548  loss_box_reg_stage0: 0.08167  loss_cls_stage1: 0.07816  loss_box_reg_stage1: 0.05047  loss_cls_stage2: 0.05802  loss_box_reg_stage2: 0.0204  loss_rpn_cls: 0.157  loss_rpn_loc: 0.03232    time: 1.0364  last_time: 1.0699  data_time: 0.0271  last_data_time: 0.0089   lr: 0.00091808  max_mem: 3584M
# [07/05 23:41:49 d2.utils.events]:  eta: 3:35:52  iter: 479  total_loss: 0.5593  loss_cls_stage0: 0.1242  loss_box_reg_stage0: 0.05697  loss_cls_stage1: 0.07457  loss_box_reg_stage1: 0.04496  loss_cls_stage2: 0.05649  loss_box_reg_stage2: 0.0202  loss_rpn_cls: 0.1218  loss_rpn_loc: 0.04384    time: 1.0367  last_time: 1.0620  data_time: 0.0298  last_data_time: 0.0173   lr: 0.00095804  max_mem: 3584M
# WARNING [07/05 23:42:15 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/05 23:42:15 d2.data.datasets.coco]: Loaded 210 images in COCO format from /content/dataset/valid/_annotations.coco.json
# [07/05 23:42:15 d2.data.build]: Distribution of instances among all 7 categories:
# |  category   | #instances   |  category   | #instances   |   category    | #instances   |
# |:-----------:|:-------------|:-----------:|:-------------|:-------------:|:-------------|
# | components  | 0            | Alt Energy  | 74           | Circuit Bre.. | 182          |
# |   Control   | 38           | Power Lines | 41           |    Reactor    | 72           |
# | Transformer | 118          |             |              |               |              |
# |    total    | 525          |             |              |               |              |
# [07/05 23:42:15 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(640, 640), max_size=640, sample_style='choice')]
# [07/05 23:42:15 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/05 23:42:15 d2.data.common]: Serializing 210 elements to byte tensors and concatenating them all ...
# [07/05 23:42:15 d2.data.common]: Serialized dataset takes 0.07 MiB
# WARNING [07/05 23:42:15 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [07/05 23:42:15 d2.evaluation.evaluator]: Start inference on 210 batches
# [07/05 23:42:16 d2.evaluation.evaluator]: Inference done 11/210. Dataloading: 0.0026 s/iter. Inference: 0.1150 s/iter. Eval: 0.0002 s/iter. Total: 0.1178 s/iter. ETA=0:00:23
# [07/05 23:42:21 d2.evaluation.evaluator]: Inference done 55/210. Dataloading: 0.0024 s/iter. Inference: 0.1136 s/iter. Eval: 0.0002 s/iter. Total: 0.1163 s/iter. ETA=0:00:18
# [07/05 23:42:26 d2.evaluation.evaluator]: Inference done 99/210. Dataloading: 0.0021 s/iter. Inference: 0.1134 s/iter. Eval: 0.0002 s/iter. Total: 0.1158 s/iter. ETA=0:00:12
# [07/05 23:42:31 d2.evaluation.evaluator]: Inference done 140/210. Dataloading: 0.0022 s/iter. Inference: 0.1152 s/iter. Eval: 0.0002 s/iter. Total: 0.1177 s/iter. ETA=0:00:08
# [07/05 23:42:36 d2.evaluation.evaluator]: Inference done 183/210. Dataloading: 0.0021 s/iter. Inference: 0.1152 s/iter. Eval: 0.0002 s/iter. Total: 0.1176 s/iter. ETA=0:00:03
# [07/05 23:42:40 d2.evaluation.evaluator]: Total inference time: 0:00:24.138330 (0.117748 s / iter per device, on 1 devices)
# [07/05 23:42:40 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:23 (0.115181 s / iter per device, on 1 devices)
# [07/05 23:42:40 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/05 23:42:40 d2.evaluation.coco_evaluation]: Saving results to /content/drive/MyDrive/Cascade_RCNN/ResNet101/output/eval/coco_instances_results.json
# [07/05 23:42:40 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [07/05 23:42:40 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [07/05 23:42:40 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.03 seconds.
# [07/05 23:42:40 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/05 23:42:40 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.02 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.010
# [07/05 23:42:40 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |  AP   |  AP50  |  AP75  |  APs  |  APm  |  APl  |
# |:-----:|:------:|:------:|:-----:|:-----:|:-----:|
# | 0.284 | 2.024  | 0.000  | 0.000 | 0.016 | 0.350 |
# [07/05 23:42:40 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category    | AP    | category    | AP    | category        | AP    |
# |:------------|:------|:------------|:------|:----------------|:------|
# | components  | nan   | Alt Energy  | 0.025 | Circuit Breaker | 0.014 |
# | Control     | 1.467 | Power Lines | 0.000 | Reactor         | 0.198 |
# | Transformer | 0.000 |             |       |                 |       |
# [07/05 23:42:40 d2.engine.defaults]: Evaluation results for substation_valid in csv format:
# [07/05 23:42:40 d2.evaluation.testing]: copypaste: Task: bbox
# [07/05 23:42:40 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [07/05 23:42:40 d2.evaluation.testing]: copypaste: 0.2839,2.0235,0.0000,0.0000,0.0161,0.3496
# [07/05 23:42:40 d2.utils.events]:  eta: 3:35:51  iter: 499  total_loss: 0.59  loss_cls_stage0: 0.1792  loss_box_reg_stage0: 0.1062  loss_cls_stage1: 0.09316  loss_box_reg_stage1: 0.06148  loss_cls_stage2: 0.04651  loss_box_reg_stage2: 0.02293  loss_rpn_cls: 0.06103  loss_rpn_loc: 0.02289    time: 1.0371  last_time: 0.9910  data_time: 0.0242  last_data_time: 0.0223   lr: 0.000998  max_mem: 3584M
# [07/05 23:43:01 d2.utils.events]:  eta: 3:35:49  iter: 519  total_loss: 0.745  loss_cls_stage0: 0.1403  loss_box_reg_stage0: 0.08793  loss_cls_stage1: 0.0824  loss_box_reg_stage1: 0.05499  loss_cls_stage2: 0.04733  loss_box_reg_stage2: 0.0225  loss_rpn_cls: 0.09996  loss_rpn_loc: 0.102    time: 1.0385  last_time: 1.1168  data_time: 0.0246  last_data_time: 0.0359   lr: 0.001  max_mem: 3584M
# [07/05 23:43:22 d2.utils.events]:  eta: 3:35:27  iter: 539  total_loss: 0.6225  loss_cls_stage0: 0.1559  loss_box_reg_stage0: 0.1053  loss_cls_stage1: 0.08872  loss_box_reg_stage1: 0.06929  loss_cls_stage2: 0.04872  loss_box_reg_stage2: 0.02243  loss_rpn_cls: 0.06271  loss_rpn_loc: 0.0349    time: 1.0382  last_time: 0.9905  data_time: 0.0259  last_data_time: 0.0125   lr: 0.001  max_mem: 3584M
# ...
# [07/06 03:40:35 d2.data.common]: Serializing 210 elements to byte tensors and concatenating them all ...
# [07/06 03:40:35 d2.data.common]: Serialized dataset takes 0.07 MiB
# WARNING [07/06 03:40:35 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [07/06 03:40:35 d2.evaluation.evaluator]: Start inference on 210 batches
# [07/06 03:40:37 d2.evaluation.evaluator]: Inference done 11/210. Dataloading: 0.0011 s/iter. Inference: 0.1203 s/iter. Eval: 0.0002 s/iter. Total: 0.1217 s/iter. ETA=0:00:24
# [07/06 03:40:42 d2.evaluation.evaluator]: Inference done 52/210. Dataloading: 0.0016 s/iter. Inference: 0.1203 s/iter. Eval: 0.0003 s/iter. Total: 0.1222 s/iter. ETA=0:00:19
# [07/06 03:40:47 d2.evaluation.evaluator]: Inference done 86/210. Dataloading: 0.0023 s/iter. Inference: 0.1303 s/iter. Eval: 0.0005 s/iter. Total: 0.1332 s/iter. ETA=0:00:16
# [07/06 03:40:52 d2.evaluation.evaluator]: Inference done 121/210. Dataloading: 0.0025 s/iter. Inference: 0.1332 s/iter. Eval: 0.0005 s/iter. Total: 0.1364 s/iter. ETA=0:00:12
# [07/06 03:40:57 d2.evaluation.evaluator]: Inference done 159/210. Dataloading: 0.0024 s/iter. Inference: 0.1328 s/iter. Eval: 0.0005 s/iter. Total: 0.1358 s/iter. ETA=0:00:06
# [07/06 03:41:02 d2.evaluation.evaluator]: Inference done 196/210. Dataloading: 0.0023 s/iter. Inference: 0.1331 s/iter. Eval: 0.0004 s/iter. Total: 0.1360 s/iter. ETA=0:00:01
# [07/06 03:41:04 d2.evaluation.evaluator]: Total inference time: 0:00:27.898202 (0.136089 s / iter per device, on 1 devices)
# [07/06 03:41:04 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:27 (0.132929 s / iter per device, on 1 devices)
# [07/06 03:41:04 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/06 03:41:04 d2.evaluation.coco_evaluation]: Saving results to /content/drive/MyDrive/Cascade_RCNN/ResNet101/output/eval/coco_instances_results.json
# [07/06 03:41:04 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [07/06 03:41:04 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [07/06 03:41:04 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.05 seconds.
# [07/06 03:41:04 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/06 03:41:04 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.03 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.318
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.604
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.284
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.299
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.373
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.291
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.481
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.496
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.217
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.534
# [07/06 03:41:04 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 31.810 | 60.431 | 28.386 | 10.031 | 29.882 | 37.318 |
# [07/06 03:41:04 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category    | AP     | category    | AP     | category        | AP     |
# |:------------|:-------|:------------|:-------|:----------------|:-------|
# | components  | nan    | Alt Energy  | 15.866 | Circuit Breaker | 22.803 |
# | Control     | 57.309 | Power Lines | 29.781 | Reactor         | 28.662 |
# | Transformer | 36.438 |             |        |                 |        |
# [07/06 03:41:04 d2.engine.defaults]: Evaluation results for substation_valid in csv format:
# [07/06 03:41:04 d2.evaluation.testing]: copypaste: Task: bbox
# [07/06 03:41:04 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [07/06 03:41:04 d2.evaluation.testing]: copypaste: 31.8098,60.4315,28.3857,10.0313,29.8820,37.3180
# Training complete.
# Using checkpoint: /content/drive/MyDrive/Cascade_RCNN/ResNet101/output/model_final.pth
# [07/06 03:41:05 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from /content/drive/MyDrive/Cascade_RCNN/ResNet101/output/model_final.pth ...
#
# === Validation Set ===
# WARNING [07/06 03:41:07 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# WARNING [07/06 03:41:07 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/06 03:41:07 d2.data.datasets.coco]: Loaded 210 images in COCO format from /content/dataset/valid/_annotations.coco.json
# [07/06 03:41:07 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(640, 640), max_size=640, sample_style='choice')]
# [07/06 03:41:07 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/06 03:41:07 d2.data.common]: Serializing 210 elements to byte tensors and concatenating them all ...
# [07/06 03:41:07 d2.data.common]: Serialized dataset takes 0.07 MiB
# [07/06 03:41:07 d2.evaluation.evaluator]: Start inference on 210 batches
# [07/06 03:41:08 d2.evaluation.evaluator]: Inference done 11/210. Dataloading: 0.0012 s/iter. Inference: 0.1275 s/iter. Eval: 0.0003 s/iter. Total: 0.1289 s/iter. ETA=0:00:25
# [07/06 03:41:13 d2.evaluation.evaluator]: Inference done 51/210. Dataloading: 0.0017 s/iter. Inference: 0.1263 s/iter. Eval: 0.0003 s/iter. Total: 0.1283 s/iter. ETA=0:00:20
# [07/06 03:41:18 d2.evaluation.evaluator]: Inference done 91/210. Dataloading: 0.0020 s/iter. Inference: 0.1249 s/iter. Eval: 0.0003 s/iter. Total: 0.1272 s/iter. ETA=0:00:15
# [07/06 03:41:24 d2.evaluation.evaluator]: Inference done 131/210. Dataloading: 0.0019 s/iter. Inference: 0.1248 s/iter. Eval: 0.0003 s/iter. Total: 0.1270 s/iter. ETA=0:00:10
# [07/06 03:41:29 d2.evaluation.evaluator]: Inference done 171/210. Dataloading: 0.0018 s/iter. Inference: 0.1247 s/iter. Eval: 0.0003 s/iter. Total: 0.1269 s/iter. ETA=0:00:04
# [07/06 03:41:34 d2.evaluation.evaluator]: Total inference time: 0:00:26.056532 (0.127105 s / iter per device, on 1 devices)
# [07/06 03:41:34 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:25 (0.124664 s / iter per device, on 1 devices)
# [07/06 03:41:34 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/06 03:41:34 d2.evaluation.coco_evaluation]: Saving results to /content/drive/MyDrive/Cascade_RCNN/ResNet101/output/eval_valid/coco_instances_results.json
# [07/06 03:41:34 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [07/06 03:41:34 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [07/06 03:41:34 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.04 seconds.
# [07/06 03:41:34 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/06 03:41:34 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.03 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.294
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.548
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.270
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.090
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.281
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.345
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.272
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.406
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.146
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.385
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.439
# [07/06 03:41:34 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 29.432 | 54.765 | 27.027 | 8.957 | 28.058 | 34.499 |
# [07/06 03:41:34 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category    | AP     | category    | AP     | category        | AP     |
# |:------------|:-------|:------------|:-------|:----------------|:-------|
# | components  | nan    | Alt Energy  | 12.791 | Circuit Breaker | 21.572 |
# | Control     | 54.092 | Power Lines | 27.022 | Reactor         | 26.477 |
# | Transformer | 34.636 |             |        |                 |        |
# OrderedDict({'bbox': {'AP': 29.431689160602247, 'AP50': 54.76499977892163, 'AP75': 27.027275463280475, 'APs': 8.956936582493412, 'APm': 28.058374908875276, 'APl': 34.49896885411115, 'AP-components': nan, 'AP-Alt Energy': 12.791181338200678, 'AP-Circuit Breaker': 21.572173848020178, 'AP-Control': 54.09171553532829, 'AP-Power Lines': 27.022077182962246, 'AP-Reactor': 26.47708396424316, 'AP-Transformer': 34.63590309485896}})
#
# === Test Set ===
# WARNING [07/06 03:41:34 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# WARNING [07/06 03:41:34 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/06 03:41:34 d2.data.datasets.coco]: Loaded 137 images in COCO format from /content/dataset/test/_annotations.coco.json
# [07/06 03:41:34 d2.data.build]: Distribution of instances among all 7 categories:
# |  category   | #instances   |  category   | #instances   |   category    | #instances   |
# |:-----------:|:-------------|:-----------:|:-------------|:-------------:|:-------------|
# | components  | 0            | Alt Energy  | 54           | Circuit Bre.. | 153          |
# |   Control   | 19           | Power Lines | 32           |    Reactor    | 58           |
# | Transformer | 61           |             |              |               |              |
# |    total    | 377          |             |              |               |              |
# [07/06 03:41:34 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(640, 640), max_size=640, sample_style='choice')]
# [07/06 03:41:34 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/06 03:41:34 d2.data.common]: Serializing 137 elements to byte tensors and concatenating them all ...
# [07/06 03:41:34 d2.data.common]: Serialized dataset takes 0.04 MiB
# [07/06 03:41:34 d2.evaluation.evaluator]: Start inference on 137 batches
# [07/06 03:41:35 d2.evaluation.evaluator]: Inference done 11/137. Dataloading: 0.0012 s/iter. Inference: 0.1219 s/iter. Eval: 0.0003 s/iter. Total: 0.1234 s/iter. ETA=0:00:15
# [07/06 03:41:40 d2.evaluation.evaluator]: Inference done 52/137. Dataloading: 0.0015 s/iter. Inference: 0.1225 s/iter. Eval: 0.0002 s/iter. Total: 0.1243 s/iter. ETA=0:00:10
# [07/06 03:41:45 d2.evaluation.evaluator]: Inference done 93/137. Dataloading: 0.0017 s/iter. Inference: 0.1225 s/iter. Eval: 0.0003 s/iter. Total: 0.1246 s/iter. ETA=0:00:05
# [07/06 03:41:51 d2.evaluation.evaluator]: Inference done 135/137. Dataloading: 0.0017 s/iter. Inference: 0.1216 s/iter. Eval: 0.0003 s/iter. Total: 0.1237 s/iter. ETA=0:00:00
# [07/06 03:41:51 d2.evaluation.evaluator]: Total inference time: 0:00:16.366837 (0.123991 s / iter per device, on 1 devices)
# [07/06 03:41:51 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:16 (0.121588 s / iter per device, on 1 devices)
# [07/06 03:41:51 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/06 03:41:51 d2.evaluation.coco_evaluation]: Saving results to /content/drive/MyDrive/Cascade_RCNN/ResNet101/output/eval_test/coco_instances_results.json
# [07/06 03:41:51 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [07/06 03:41:51 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [07/06 03:41:51 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.03 seconds.
# [07/06 03:41:51 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/06 03:41:51 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.02 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.225
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.445
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.072
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.156
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.268
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.327
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.332
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.293
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.364
# [07/06 03:41:51 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 22.513 | 44.471 | 19.284 | 7.181 | 15.587 | 26.755 |
# [07/06 03:41:51 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category    | AP     | category    | AP     | category        | AP     |
# |:------------|:-------|:------------|:-------|:----------------|:-------|
# | components  | nan    | Alt Energy  | 10.556 | Circuit Breaker | 15.607 |
# | Control     | 55.063 | Power Lines | 27.855 | Reactor         | 15.886 |
# | Transformer | 10.112 |             |        |                 |        |
# OrderedDict({'bbox': {'AP': 22.51319584140797, 'AP50': 44.47121819968219, 'AP75': 19.28391954880802, 'APs': 7.181100564588672, 'APm': 15.586973738582408, 'APl': 26.755486112506755, 'AP-components': nan, 'AP-Alt Energy': 10.55605439753695, 'AP-Circuit Breaker': 15.607437281242815, 'AP-Control': 55.06304476601507, 'AP-Power Lines': 27.8550438266502, 'AP-Reactor': 15.885907058459589, 'AP-Transformer': 10.11168771854324}})
#
# =================================================================
#   FINAL RESULTS — Cascade R-CNN ResNet-101 FPN
# =================================================================
#
# (a) Overall Performance (mAP@50):
#     Validation : 54.76
#     Test       : 44.47
#
# (b) Overall Performance (mAP@50:95):
#     Validation : 29.43
#     Test       : 22.51
#
# (c) Alt Energy (AP test): 10.56
# (d) Circuit Breaker (AP test): 15.61
# (e) Control (AP test): 55.06
# (f) Power Lines (AP test): 27.86
# (g) Reactor (AP test): 15.89
# (h) Transformer (AP test): 10.11
# =================================================================
#
# CSV saved to: /content/drive/MyDrive/Cascade_RCNN/ResNet101/results_for_charts.csv
# Checkpoint saved at: /content/drive/MyDrive/Cascade_RCNN/ResNet101/output/model_final.pth
# Everything saved directly to Google Drive.
