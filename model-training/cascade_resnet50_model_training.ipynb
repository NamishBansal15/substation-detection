# %% [markdown]
# <a href="https://colab.research.google.com/github/NamishBansal15/substation-detection/blob/main/model-training/cascade_resnet50_model_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ═══════════════════════════════════════════════════════════════════════════
# INSTALL ALL DEPENDENCIES — run this first
# ═══════════════════════════════════════════════════════════════════════════
import os
os.chdir('/content')

# Detectron2 (matches your CUDA/PyTorch from before)
# !python -m pip install -q 'git+https://github.com/facebookresearch/detectron2.git'

# Roboflow
# !pip install -q roboflow

# Verify
import detectron2
import roboflow
print(f'Detectron2: {detectron2.__version__}')
print('Roboflow installed.')
print('All dependencies ready.')
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.5/155.5 kB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 43.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.8/269.8 kB 26.5 MB/s eta 0:00:00
#   Building wheel for detectron2 (setup.py) ... done
#   Building wheel for fvcore (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.3/260.3 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 63.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 84.1 MB/s eta 0:00:00
# Detectron2: 0.6
# Roboflow installed.
# All dependencies ready.

# %%
# ═══════════════════════════════════════════════════════════════════════════
# CASCADE R-CNN RESNET-50 FPN — COMPLETE PIPELINE IN ONE CELL
# Saves directly to Drive during training so disconnects can't lose progress
# ═══════════════════════════════════════════════════════════════════════════

import os, json, glob, getpass, csv
from google.colab import drive
from roboflow import Roboflow
from detectron2 import model_zoo
from detectron2.config import get_cfg
from detectron2.data.datasets import register_coco_instances
from detectron2.data import MetadataCatalog, DatasetCatalog, build_detection_test_loader
from detectron2.engine import DefaultTrainer, DefaultPredictor
from detectron2.evaluation import COCOEvaluator, inference_on_dataset

# ── 1. Mount Drive ────────────────────────────────────────────────────────
drive.mount('/content/drive')
DRIVE_OUTPUT_DIR = '/content/drive/MyDrive/Cascade_RCNN/ResNet50'
os.makedirs(DRIVE_OUTPUT_DIR, exist_ok=True)

# ── 2. Download dataset from Roboflow ─────────────────────────────────────
RF_API_KEY   = getpass.getpass('Roboflow API Key: ')
RF_WORKSPACE = input('Workspace name: ').strip()
RF_PROJECT   = input('Project name: ').strip()
RF_VERSION   = int(input('Version number: ').strip())

rf = Roboflow(api_key=RF_API_KEY)
project = rf.workspace(RF_WORKSPACE).project(RF_PROJECT)
version = project.version(RF_VERSION)
dataset = version.download('coco', location='/content/dataset')
DATASET_ROOT = '/content/dataset'

# ── 3. Verify dataset + detect classes ────────────────────────────────────
TRAIN_DIR = f'{DATASET_ROOT}/train'
VALID_DIR = f'{DATASET_ROOT}/valid'
TEST_DIR  = f'{DATASET_ROOT}/test'

def find_ann(split_dir):
    for fname in ['_annotations.coco.json', 'annotations.json']:
        path = f'{split_dir}/{fname}'
        if os.path.exists(path):
            return path
    raise FileNotFoundError(f'No annotation file in {split_dir}')

TRAIN_ANN = find_ann(TRAIN_DIR)
VALID_ANN = find_ann(VALID_DIR)
TEST_ANN  = find_ann(TEST_DIR)

with open(TRAIN_ANN) as f:
    coco_data = json.load(f)
CLASSES = [cat['name'] for cat in sorted(coco_data['categories'], key=lambda x: x['id'])]
NUM_CLASSES = len(CLASSES)
print(f'Classes ({NUM_CLASSES}): {CLASSES}')

# ── 4. Register datasets ──────────────────────────────────────────────────
for split in ['train', 'valid', 'test']:
    name = f'substation_{split}'
    if name in DatasetCatalog:
        DatasetCatalog.remove(name)
        MetadataCatalog.remove(name)

register_coco_instances('substation_train', {}, TRAIN_ANN, TRAIN_DIR)
register_coco_instances('substation_valid', {}, VALID_ANN, VALID_DIR)
register_coco_instances('substation_test',  {}, TEST_ANN,  TEST_DIR)
for split in ['train', 'valid', 'test']:
    MetadataCatalog.get(f'substation_{split}').thing_classes = CLASSES

# ── 5. Configure Cascade R-CNN ResNet-50 FPN ──────────────────────────────
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file('Misc/cascade_mask_rcnn_R_50_FPN_3x.yaml'))
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url('Misc/cascade_mask_rcnn_R_50_FPN_3x.yaml')

cfg.DATASETS.TRAIN = ('substation_train',)
cfg.DATASETS.TEST  = ('substation_valid',)
cfg.DATALOADER.NUM_WORKERS = 2

cfg.SOLVER.IMS_PER_BATCH     = 4
cfg.SOLVER.BASE_LR           = 0.001
cfg.SOLVER.WARMUP_FACTOR     = 0.001
cfg.SOLVER.MAX_ITER          = 13000
cfg.SOLVER.STEPS             = (9000, 12000)
cfg.SOLVER.GAMMA             = 0.1
cfg.SOLVER.CHECKPOINT_PERIOD = 500
cfg.SOLVER.WARMUP_ITERS      = 500
cfg.TEST.EVAL_PERIOD         = 500

cfg.MODEL.ROI_HEADS.NUM_CLASSES = NUM_CLASSES
cfg.MODEL.MASK_ON = False

cfg.INPUT.MIN_SIZE_TRAIN = (640,)
cfg.INPUT.MAX_SIZE_TRAIN = 640
cfg.INPUT.MIN_SIZE_TEST  = 640
cfg.INPUT.MAX_SIZE_TEST  = 640

cfg.OUTPUT_DIR = f'{DRIVE_OUTPUT_DIR}/output'
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

print(f'Output saving directly to Drive: {cfg.OUTPUT_DIR}')
print(f'Backbone: ResNet-50')
print(f'Max iterations: {cfg.SOLVER.MAX_ITER} (~50 epochs)')

# ── 6. Train ──────────────────────────────────────────────────────────────
class TrainerWithEval(DefaultTrainer):
    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            output_folder = os.path.join(cfg.OUTPUT_DIR, 'eval')
        return COCOEvaluator(dataset_name, cfg, False, output_folder)

trainer = TrainerWithEval(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
print('Training complete.')

# ── 7. Load best checkpoint ───────────────────────────────────────────────
ckpts = sorted(glob.glob(f'{cfg.OUTPUT_DIR}/model_*.pth'))
BEST_CKPT = ckpts[-1] if ckpts else os.path.join(cfg.OUTPUT_DIR, 'model_final.pth')
print(f'Using checkpoint: {BEST_CKPT}')

cfg.MODEL.WEIGHTS = BEST_CKPT
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.3
predictor = DefaultPredictor(cfg)

# ── 8. Evaluate on validation set ─────────────────────────────────────────
print('\n=== Validation Set ===')
val_evaluator = COCOEvaluator('substation_valid', cfg, False, output_dir=f'{cfg.OUTPUT_DIR}/eval_valid')
val_loader = build_detection_test_loader(cfg, 'substation_valid')
val_results = inference_on_dataset(predictor.model, val_loader, val_evaluator)
print(val_results)

# ── 9. Evaluate on test set ───────────────────────────────────────────────
print('\n=== Test Set ===')
test_evaluator = COCOEvaluator('substation_test', cfg, False, output_dir=f'{cfg.OUTPUT_DIR}/eval_test')
test_loader = build_detection_test_loader(cfg, 'substation_test')
test_results = inference_on_dataset(predictor.model, test_loader, test_evaluator)
print(test_results)

# ── 10. Summary table + chart stats ──────────────────────────────────────
MODEL_NAME = 'Cascade R-CNN ResNet-50 FPN'

val_ap50 = val_results['bbox'].get('AP50')
val_ap   = val_results['bbox'].get('AP')
test_ap50 = test_results['bbox'].get('AP50')
test_ap   = test_results['bbox'].get('AP')

per_class = {}
for k, v in test_results['bbox'].items():
    if k.startswith('AP-'):
        per_class[k.replace('AP-', '')] = v

target_classes = ['Alt Energy', 'Circuit Breaker', 'Control', 'Power Lines', 'Reactor', 'Transformer']
panel_labels   = ['(c)', '(d)', '(e)', '(f)', '(g)', '(h)']

print('\n' + '=' * 65)
print(f'  FINAL RESULTS — {MODEL_NAME}')
print('=' * 65)
print(f'\n(a) Overall Performance (mAP@50):')
print(f'    Validation : {val_ap50:.2f}')
print(f'    Test       : {test_ap50:.2f}')
print(f'\n(b) Overall Performance (mAP@50:95):')
print(f'    Validation : {val_ap:.2f}')
print(f'    Test       : {test_ap:.2f}')
print()
for label, cls in zip(panel_labels, target_classes):
    val = per_class.get(cls, float('nan'))
    print(f'{label} {cls} (AP test): {val:.2f}')

print('=' * 65)

# ── 11. Save CSV to Drive ─────────────────────────────────────────────────
csv_path = f'{DRIVE_OUTPUT_DIR}/results_for_charts.csv'
rows = [
    ['Metric', 'Validation', 'Test'],
    ['mAP@50 Overall',    f'{val_ap50:.2f}',  f'{test_ap50:.2f}'],
    ['mAP@50:95 Overall', f'{val_ap:.2f}',    f'{test_ap:.2f}'],
]
for cls in target_classes:
    v = per_class.get(cls, float('nan'))
    rows.append([f'AP - {cls}', 'N/A', f'{v:.2f}'])

with open(csv_path, 'w', newline='') as f:
    csv.writer(f).writerows(rows)

print(f'\nCSV saved to: {csv_path}')
print(f'Checkpoint saved at: {BEST_CKPT}')
print('Everything saved directly to Google Drive.')
# Out:
# Mounted at /content/drive
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in /content/dataset to coco:: 100%|██████████| 60558/60558 [00:01<00:00, 47676.62it/s]
# Extracting Dataset Version Zip to /content/dataset in coco:: 100%|██████████| 1397/1397 [00:00<00:00, 5776.43it/s]
# Classes (7): ['components', 'Alt Energy', 'Circuit Breaker', 'Control', 'Power Lines', 'Reactor', 'Transformer']
# Output saving directly to Drive: /content/drive/MyDrive/Cascade_RCNN/ResNet50/output
# Backbone: ResNet-50
# Max iterations: 13000 (~50 epochs)
# [07/07 01:51:32 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): CascadeROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): ModuleList(
#       (0-2): 3 x FastRCNNConvFCHead(
#         (flatten): Flatten(start_dim=1, end_dim=-1)
#         (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#         (fc_relu1): ReLU()
#         (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#         (fc_relu2): ReLU()
#       )
#     )
#     (box_predictor): ModuleList(
#       (0-2): 3 x FastRCNNOutputLayers(
#         (cls_score): Linear(in_features=1024, out_features=8, bias=True)
#         (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#       )
#     )
#   )
# )
# WARNING [07/07 01:51:32 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/07 01:51:32 d2.data.datasets.coco]: Loaded 1042 images in COCO format from /content/dataset/train/_annotations.coco.json
# [07/07 01:51:32 d2.data.build]: Removed 1 images with no usable annotations. 1041 images left.
# [07/07 01:51:32 d2.data.build]: Distribution of instances among all 7 categories:
# |  category   | #instances   |  category   | #instances   |   category    | #instances   |
# |:-----------:|:-------------|:-----------:|:-------------|:-------------:|:-------------|
# | components  | 0            | Alt Energy  | 419          | Circuit Bre.. | 1022         |
# |   Control   | 206          | Power Lines | 177          |    Reactor    | 366          |
# | Transformer | 541          |             |              |               |              |
# |    total    | 2731         |             |              |               |              |
# [07/07 01:51:32 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640,), max_size=640, sample_style='choice'), RandomFlip()]
# [07/07 01:51:32 d2.data.build]: Using training sampler TrainingSampler
# [07/07 01:51:32 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/07 01:51:32 d2.data.common]: Serializing 1041 elements to byte tensors and concatenating them all ...
# [07/07 01:51:32 d2.data.common]: Serialized dataset takes 0.34 MiB
# [07/07 01:51:32 d2.data.build]: Making batched data loader with batch_size=4
# [07/07 01:51:32 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/Misc/cascade_mask_rcnn_R_50_FPN_3x/144998488/model_final_480dd8.pkl ...
# model_final_480dd8.pkl: 288MB [00:07, 38.3MB/s]
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.0.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (8, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.0.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (8,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.1.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (8, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.1.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (8,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.2.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (8, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.2.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (8,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.0.cls_score.{bias, weight}
# roi_heads.box_predictor.1.cls_score.{bias, weight}
# roi_heads.box_predictor.2.cls_score.{bias, weight}
# WARNING:fvcore.common.checkpoint:The checkpoint state_dict contains keys that are not used by the model:
#   roi_heads.mask_head.mask_fcn1.{bias, weight}
#   roi_heads.mask_head.mask_fcn2.{bias, weight}
#   roi_heads.mask_head.mask_fcn3.{bias, weight}
#   roi_heads.mask_head.mask_fcn4.{bias, weight}
#   roi_heads.mask_head.deconv.{bias, weight}
#   roi_heads.mask_head.predictor.{bias, weight}
# [07/07 01:51:40 d2.engine.train_loop]: Starting training from iteration 0
# torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4381.)
# W0707 01:51:44.345000 341 torch/fx/_symbolic_trace.py:53] is_fx_tracing will return true for both fx.symbolic_trace and torch.export. Please use is_fx_tracing_symbolic_tracing() for specifically fx.symbolic_trace or torch.compiler.is_compiling() for specifically torch.export/compile.
# [07/07 01:51:58 d2.utils.events]:  eta: 2:23:08  iter: 19  total_loss: 6.914  loss_cls_stage0: 2.122  loss_box_reg_stage0: 0.1173  loss_cls_stage1: 2.037  loss_box_reg_stage1: 0.1518  loss_cls_stage2: 2.23  loss_box_reg_stage2: 0.1012  loss_rpn_cls: 0.1018  loss_rpn_loc: 0.01936    time: 0.6670  last_time: 0.6920  data_time: 0.0401  last_data_time: 0.0435   lr: 3.8962e-05  max_mem: 2433M
# [07/07 01:52:15 d2.utils.events]:  eta: 2:24:07  iter: 39  total_loss: 4.916  loss_cls_stage0: 1.427  loss_box_reg_stage0: 0.1325  loss_cls_stage1: 1.37  loss_box_reg_stage1: 0.1761  loss_cls_stage2: 1.461  loss_box_reg_stage2: 0.09762  loss_rpn_cls: 0.0861  loss_rpn_loc: 0.02488    time: 0.6749  last_time: 0.6633  data_time: 0.0300  last_data_time: 0.0206   lr: 7.8922e-05  max_mem: 2433M
# [07/07 01:52:29 d2.utils.events]:  eta: 2:25:28  iter: 59  total_loss: 1.964  loss_cls_stage0: 0.3901  loss_box_reg_stage0: 0.1239  loss_cls_stage1: 0.3731  loss_box_reg_stage1: 0.1531  loss_cls_stage2: 0.3426  loss_box_reg_stage2: 0.1119  loss_rpn_cls: 0.1309  loss_rpn_loc: 0.01857    time: 0.6823  last_time: 0.6703  data_time: 0.0293  last_data_time: 0.0238   lr: 0.00011888  max_mem: 2434M
# [07/07 01:52:43 d2.utils.events]:  eta: 2:28:07  iter: 79  total_loss: 1.095  loss_cls_stage0: 0.2349  loss_box_reg_stage0: 0.1356  loss_cls_stage1: 0.1897  loss_box_reg_stage1: 0.1735  loss_cls_stage2: 0.1392  loss_box_reg_stage2: 0.1129  loss_rpn_cls: 0.07186  loss_rpn_loc: 0.01885    time: 0.6882  last_time: 0.7179  data_time: 0.0291  last_data_time: 0.0212   lr: 0.00015884  max_mem: 2436M
# [07/07 01:52:58 d2.utils.events]:  eta: 2:29:56  iter: 99  total_loss: 1.181  loss_cls_stage0: 0.2543  loss_box_reg_stage0: 0.1468  loss_cls_stage1: 0.2233  loss_box_reg_stage1: 0.1839  loss_cls_stage2: 0.14  loss_box_reg_stage2: 0.1063  loss_rpn_cls: 0.0621  loss_rpn_loc: 0.02185    time: 0.6958  last_time: 0.7296  data_time: 0.0311  last_data_time: 0.0286   lr: 0.0001988  max_mem: 2436M
# [07/07 01:53:13 d2.utils.events]:  eta: 2:31:27  iter: 119  total_loss: 1.125  loss_cls_stage0: 0.2298  loss_box_reg_stage0: 0.1327  loss_cls_stage1: 0.2025  loss_box_reg_stage1: 0.1884  loss_cls_stage2: 0.1279  loss_box_reg_stage2: 0.1357  loss_rpn_cls: 0.0505  loss_rpn_loc: 0.01918    time: 0.7041  last_time: 0.7584  data_time: 0.0299  last_data_time: 0.0252   lr: 0.00023876  max_mem: 2436M
# [07/07 01:53:28 d2.utils.events]:  eta: 2:32:29  iter: 139  total_loss: 1.051  loss_cls_stage0: 0.2442  loss_box_reg_stage0: 0.1443  loss_cls_stage1: 0.1682  loss_box_reg_stage1: 0.1734  loss_cls_stage2: 0.1058  loss_box_reg_stage2: 0.08908  loss_rpn_cls: 0.05477  loss_rpn_loc: 0.01798    time: 0.7113  last_time: 0.7674  data_time: 0.0252  last_data_time: 0.0225   lr: 0.00027872  max_mem: 2436M
# [07/07 01:53:43 d2.utils.events]:  eta: 2:33:45  iter: 159  total_loss: 1.245  loss_cls_stage0: 0.2896  loss_box_reg_stage0: 0.1838  loss_cls_stage1: 0.2158  loss_box_reg_stage1: 0.2124  loss_cls_stage2: 0.1533  loss_box_reg_stage2: 0.1691  loss_rpn_cls: 0.03931  loss_rpn_loc: 0.02015    time: 0.7190  last_time: 0.7720  data_time: 0.0250  last_data_time: 0.0107   lr: 0.00031868  max_mem: 2436M
# [07/07 01:53:59 d2.utils.events]:  eta: 2:35:12  iter: 179  total_loss: 1.228  loss_cls_stage0: 0.2853  loss_box_reg_stage0: 0.1768  loss_cls_stage1: 0.2095  loss_box_reg_stage1: 0.2059  loss_cls_stage2: 0.1456  loss_box_reg_stage2: 0.1397  loss_rpn_cls: 0.0477  loss_rpn_loc: 0.01713    time: 0.7284  last_time: 0.8322  data_time: 0.0341  last_data_time: 0.0285   lr: 0.00035864  max_mem: 2436M
# [07/07 01:54:16 d2.utils.events]:  eta: 2:36:37  iter: 199  total_loss: 1.352  loss_cls_stage0: 0.2924  loss_box_reg_stage0: 0.2045  loss_cls_stage1: 0.2282  loss_box_reg_stage1: 0.2421  loss_cls_stage2: 0.1494  loss_box_reg_stage2: 0.1563  loss_rpn_cls: 0.04958  loss_rpn_loc: 0.02296    time: 0.7385  last_time: 0.8570  data_time: 0.0264  last_data_time: 0.0092   lr: 0.0003986  max_mem: 2436M
# [07/07 01:54:32 d2.utils.events]:  eta: 2:38:12  iter: 219  total_loss: 1.265  loss_cls_stage0: 0.241  loss_box_reg_stage0: 0.174  loss_cls_stage1: 0.2149  loss_box_reg_stage1: 0.2173  loss_cls_stage2: 0.1371  loss_box_reg_stage2: 0.1589  loss_rpn_cls: 0.04533  loss_rpn_loc: 0.01626    time: 0.7463  last_time: 0.8328  data_time: 0.0283  last_data_time: 0.0316   lr: 0.00043856  max_mem: 2436M
# [07/07 01:54:49 d2.utils.events]:  eta: 2:39:07  iter: 239  total_loss: 1.286  loss_cls_stage0: 0.2513  loss_box_reg_stage0: 0.1738  loss_cls_stage1: 0.2187  loss_box_reg_stage1: 0.2457  loss_cls_stage2: 0.1555  loss_box_reg_stage2: 0.2004  loss_rpn_cls: 0.03096  loss_rpn_loc: 0.0173    time: 0.7525  last_time: 0.7828  data_time: 0.0268  last_data_time: 0.0093   lr: 0.00047852  max_mem: 2436M
# [07/07 01:55:05 d2.utils.events]:  eta: 2:40:55  iter: 259  total_loss: 1.256  loss_cls_stage0: 0.2689  loss_box_reg_stage0: 0.1839  loss_cls_stage1: 0.2241  loss_box_reg_stage1: 0.2424  loss_cls_stage2: 0.1491  loss_box_reg_stage2: 0.1905  loss_rpn_cls: 0.03597  loss_rpn_loc: 0.01428    time: 0.7568  last_time: 0.7885  data_time: 0.0282  last_data_time: 0.0261   lr: 0.00051848  max_mem: 2436M
# [07/07 01:55:21 d2.utils.events]:  eta: 2:42:42  iter: 279  total_loss: 1.288  loss_cls_stage0: 0.2643  loss_box_reg_stage0: 0.1834  loss_cls_stage1: 0.2163  loss_box_reg_stage1: 0.2336  loss_cls_stage2: 0.144  loss_box_reg_stage2: 0.1502  loss_rpn_cls: 0.03214  loss_rpn_loc: 0.01715    time: 0.7604  last_time: 0.8170  data_time: 0.0287  last_data_time: 0.0238   lr: 0.00055844  max_mem: 2436M
# [07/07 01:55:37 d2.utils.events]:  eta: 2:45:14  iter: 299  total_loss: 1.139  loss_cls_stage0: 0.2005  loss_box_reg_stage0: 0.1471  loss_cls_stage1: 0.1829  loss_box_reg_stage1: 0.2049  loss_cls_stage2: 0.1326  loss_box_reg_stage2: 0.1576  loss_rpn_cls: 0.02999  loss_rpn_loc: 0.01492    time: 0.7642  last_time: 0.8329  data_time: 0.0319  last_data_time: 0.0373   lr: 0.0005984  max_mem: 2436M
# [07/07 01:55:54 d2.utils.events]:  eta: 2:45:50  iter: 319  total_loss: 1.248  loss_cls_stage0: 0.2347  loss_box_reg_stage0: 0.1763  loss_cls_stage1: 0.2092  loss_box_reg_stage1: 0.2299  loss_cls_stage2: 0.1505  loss_box_reg_stage2: 0.199  loss_rpn_cls: 0.03169  loss_rpn_loc: 0.01943    time: 0.7676  last_time: 0.8054  data_time: 0.0310  last_data_time: 0.0246   lr: 0.00063836  max_mem: 2436M
# [07/07 01:56:10 d2.utils.events]:  eta: 2:46:20  iter: 339  total_loss: 1.241  loss_cls_stage0: 0.2505  loss_box_reg_stage0: 0.1801  loss_cls_stage1: 0.2107  loss_box_reg_stage1: 0.2205  loss_cls_stage2: 0.1422  loss_box_reg_stage2: 0.1592  loss_rpn_cls: 0.03952  loss_rpn_loc: 0.02016    time: 0.7703  last_time: 0.8254  data_time: 0.0267  last_data_time: 0.0268   lr: 0.00067832  max_mem: 2436M
# [07/07 01:56:26 d2.utils.events]:  eta: 2:46:30  iter: 359  total_loss: 1.507  loss_cls_stage0: 0.2858  loss_box_reg_stage0: 0.2117  loss_cls_stage1: 0.243  loss_box_reg_stage1: 0.2707  loss_cls_stage2: 0.1531  loss_box_reg_stage2: 0.2406  loss_rpn_cls: 0.03382  loss_rpn_loc: 0.01216    time: 0.7725  last_time: 0.7878  data_time: 0.0258  last_data_time: 0.0260   lr: 0.00071828  max_mem: 2436M
# [07/07 01:56:42 d2.utils.events]:  eta: 2:47:01  iter: 379  total_loss: 1.376  loss_cls_stage0: 0.248  loss_box_reg_stage0: 0.171  loss_cls_stage1: 0.2307  loss_box_reg_stage1: 0.269  loss_cls_stage2: 0.156  loss_box_reg_stage2: 0.2165  loss_rpn_cls: 0.02187  loss_rpn_loc: 0.01646    time: 0.7749  last_time: 0.8095  data_time: 0.0267  last_data_time: 0.0253   lr: 0.00075824  max_mem: 2436M
# [07/07 01:56:59 d2.utils.events]:  eta: 2:47:26  iter: 399  total_loss: 1.292  loss_cls_stage0: 0.2351  loss_box_reg_stage0: 0.1818  loss_cls_stage1: 0.2029  loss_box_reg_stage1: 0.2792  loss_cls_stage2: 0.1478  loss_box_reg_stage2: 0.1819  loss_rpn_cls: 0.02615  loss_rpn_loc: 0.01568    time: 0.7771  last_time: 0.7998  data_time: 0.0268  last_data_time: 0.0262   lr: 0.0007982  max_mem: 2436M
# [07/07 01:57:15 d2.utils.events]:  eta: 2:47:42  iter: 419  total_loss: 1.367  loss_cls_stage0: 0.23  loss_box_reg_stage0: 0.1705  loss_cls_stage1: 0.2046  loss_box_reg_stage1: 0.2696  loss_cls_stage2: 0.159  loss_box_reg_stage2: 0.2684  loss_rpn_cls: 0.02627  loss_rpn_loc: 0.01226    time: 0.7791  last_time: 0.8042  data_time: 0.0268  last_data_time: 0.0381   lr: 0.00083816  max_mem: 2436M
# [07/07 01:57:31 d2.utils.events]:  eta: 2:48:04  iter: 439  total_loss: 1.104  loss_cls_stage0: 0.193  loss_box_reg_stage0: 0.1417  loss_cls_stage1: 0.1775  loss_box_reg_stage1: 0.2362  loss_cls_stage2: 0.1337  loss_box_reg_stage2: 0.1952  loss_rpn_cls: 0.03172  loss_rpn_loc: 0.01227    time: 0.7803  last_time: 0.8173  data_time: 0.0252  last_data_time: 0.0255   lr: 0.00087812  max_mem: 2436M
# [07/07 01:57:48 d2.utils.events]:  eta: 2:47:52  iter: 459  total_loss: 1.405  loss_cls_stage0: 0.2401  loss_box_reg_stage0: 0.1713  loss_cls_stage1: 0.219  loss_box_reg_stage1: 0.2823  loss_cls_stage2: 0.1644  loss_box_reg_stage2: 0.2219  loss_rpn_cls: 0.02802  loss_rpn_loc: 0.01325    time: 0.7816  last_time: 0.7837  data_time: 0.0268  last_data_time: 0.0250   lr: 0.00091808  max_mem: 2436M
# [07/07 01:58:04 d2.utils.events]:  eta: 2:47:36  iter: 479  total_loss: 1.148  loss_cls_stage0: 0.2174  loss_box_reg_stage0: 0.1439  loss_cls_stage1: 0.1845  loss_box_reg_stage1: 0.2187  loss_cls_stage2: 0.1443  loss_box_reg_stage2: 0.2085  loss_rpn_cls: 0.043  loss_rpn_loc: 0.01639    time: 0.7826  last_time: 0.8146  data_time: 0.0286  last_data_time: 0.0156   lr: 0.00095804  max_mem: 2436M
# WARNING [07/07 01:58:28 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/07 01:58:28 d2.data.datasets.coco]: Loaded 210 images in COCO format from /content/dataset/valid/_annotations.coco.json
# [07/07 01:58:28 d2.data.build]: Distribution of instances among all 7 categories:
# |  category   | #instances   |  category   | #instances   |   category    | #instances   |
# |:-----------:|:-------------|:-----------:|:-------------|:-------------:|:-------------|
# | components  | 0            | Alt Energy  | 74           | Circuit Bre.. | 182          |
# |   Control   | 38           | Power Lines | 41           |    Reactor    | 72           |
# | Transformer | 118          |             |              |               |              |
# |    total    | 525          |             |              |               |              |
# [07/07 01:58:28 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(640, 640), max_size=640, sample_style='choice')]
# [07/07 01:58:28 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/07 01:58:28 d2.data.common]: Serializing 210 elements to byte tensors and concatenating them all ...
# [07/07 01:58:28 d2.data.common]: Serialized dataset takes 0.07 MiB
# WARNING [07/07 01:58:28 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [07/07 01:58:28 d2.evaluation.evaluator]: Start inference on 210 batches
# [07/07 01:58:29 d2.evaluation.evaluator]: Inference done 11/210. Dataloading: 0.0015 s/iter. Inference: 0.0961 s/iter. Eval: 0.0003 s/iter. Total: 0.0979 s/iter. ETA=0:00:19
# [07/07 01:58:34 d2.evaluation.evaluator]: Inference done 63/210. Dataloading: 0.0019 s/iter. Inference: 0.0959 s/iter. Eval: 0.0003 s/iter. Total: 0.0981 s/iter. ETA=0:00:14
# [07/07 01:58:39 d2.evaluation.evaluator]: Inference done 108/210. Dataloading: 0.0023 s/iter. Inference: 0.1012 s/iter. Eval: 0.0004 s/iter. Total: 0.1039 s/iter. ETA=0:00:10
# [07/07 01:58:44 d2.evaluation.evaluator]: Inference done 153/210. Dataloading: 0.0021 s/iter. Inference: 0.1037 s/iter. Eval: 0.0004 s/iter. Total: 0.1062 s/iter. ETA=0:00:06
# [07/07 01:58:49 d2.evaluation.evaluator]: Inference done 202/210. Dataloading: 0.0019 s/iter. Inference: 0.1031 s/iter. Eval: 0.0003 s/iter. Total: 0.1055 s/iter. ETA=0:00:00
# [07/07 01:58:50 d2.evaluation.evaluator]: Total inference time: 0:00:21.718209 (0.105942 s / iter per device, on 1 devices)
# [07/07 01:58:50 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:21 (0.103148 s / iter per device, on 1 devices)
# [07/07 01:58:50 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/07 01:58:50 d2.evaluation.coco_evaluation]: Saving results to /content/drive/MyDrive/Cascade_RCNN/ResNet50/output/eval/coco_instances_results.json
# [07/07 01:58:50 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# [07/07 01:58:50 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [07/07 01:58:50 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.10 seconds.
# [07/07 01:58:50 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/07 01:58:50 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.05 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.156
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.306
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.151
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.047
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.188
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.326
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.345
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.107
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.284
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.386
# [07/07 01:58:50 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm  |  APl   |
# |:------:|:------:|:------:|:-----:|:-----:|:------:|
# | 15.572 | 30.574 | 15.084 | 2.068 | 4.654 | 18.770 |
# [07/07 01:58:50 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category    | AP     | category    | AP     | category        | AP    |
# |:------------|:-------|:------------|:-------|:----------------|:------|
# | components  | nan    | Alt Energy  | 5.255  | Circuit Breaker | 3.914 |
# | Control     | 56.855 | Power Lines | 17.882 | Reactor         | 4.289 |
# | Transformer | 5.237  |             |        |                 |       |
# [07/07 01:58:50 d2.engine.defaults]: Evaluation results for substation_valid in csv format:
# [07/07 01:58:50 d2.evaluation.testing]: copypaste: Task: bbox
# [07/07 01:58:50 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [07/07 01:58:50 d2.evaluation.testing]: copypaste: 15.5719,30.5736,15.0836,2.0676,4.6543,18.7696
# [07/07 01:58:50 d2.utils.events]:  eta: 2:47:23  iter: 499  total_loss: 1.432  loss_cls_stage0: 0.2109  loss_box_reg_stage0: 0.1771  loss_cls_stage1: 0.2264  loss_box_reg_stage1: 0.317  loss_cls_stage2: 0.1694  loss_box_reg_stage2: 0.2655  loss_rpn_cls: 0.0201  loss_rpn_loc: 0.01293    time: 0.7840  last_time: 0.8393  data_time: 0.0282  last_data_time: 0.0422   lr: 0.000998  max_mem: 2436M
# [07/07 01:59:08 d2.utils.events]:  eta: 2:47:16  iter: 519  total_loss: 1.446  loss_cls_stage0: 0.2295  loss_box_reg_stage0: 0.1957  loss_cls_stage1: 0.2173  loss_box_reg_stage1: 0.2907  loss_cls_stage2: 0.1797  loss_box_reg_stage2: 0.2421  loss_rpn_cls: 0.02584  loss_rpn_loc: 0.01407    time: 0.7867  last_time: 0.8441  data_time: 0.0287  last_data_time: 0.0285   lr: 0.001  max_mem: 2436M
# [07/07 01:59:24 d2.utils.events]:  eta: 2:47:07  iter: 539  total_loss: 1.36  loss_cls_stage0: 0.2249  loss_box_reg_stage0: 0.1802  loss_cls_stage1: 0.21  loss_box_reg_stage1: 0.2938  loss_cls_stage2: 0.1432  loss_box_reg_stage2: 0.2423  loss_rpn_cls: 0.0219  loss_rpn_loc: 0.01231    time: 0.7879  last_time: 0.7972  data_time: 0.0285  last_data_time: 0.0248   lr: 0.001  max_mem: 2436M
# [07/07 01:59:40 d2.utils.events]:  eta: 2:46:52  iter: 559  total_loss: 1.197  loss_cls_stage0: 0.1743  loss_box_reg_stage0: 0.1543  loss_cls_stage1: 0.1718  loss_box_reg_stage1: 0.2697  loss_cls_stage2: 0.1411  loss_box_reg_stage2: 0.2411  loss_rpn_cls: 0.01484  loss_rpn_loc: 0.009894    time: 0.7885  last_time: 0.7980  data_time: 0.0269  last_data_time: 0.0292   lr: 0.001  max_mem: 2436M
# [07/07 01:59:56 d2.utils.events]:  eta: 2:46:45  iter: 579  total_loss: 1.19  loss_cls_stage0: 0.1858  loss_box_reg_stage0: 0.1464  loss_cls_stage1: 0.1783  loss_box_reg_stage1: 0.2445  loss_cls_stage2: 0.1368  loss_box_reg_stage2: 0.2643  loss_rpn_cls: 0.01565  loss_rpn_loc: 0.01447    time: 0.7894  last_time: 0.8080  data_time: 0.0288  last_data_time: 0.0252   lr: 0.001  max_mem: 2436M
# [07/07 02:00:13 d2.utils.events]:  eta: 2:46:40  iter: 599  total_loss: 1.266  loss_cls_stage0: 0.204  loss_box_reg_stage0: 0.1694  loss_cls_stage1: 0.2025  loss_box_reg_stage1: 0.2655  loss_cls_stage2: 0.1427  loss_box_reg_stage2: 0.2203  loss_rpn_cls: 0.0264  loss_rpn_loc: 0.01551    time: 0.7906  last_time: 0.8262  data_time: 0.0273  last_data_time: 0.0136   lr: 0.001  max_mem: 2436M
# [07/07 02:00:30 d2.utils.events]:  eta: 2:46:35  iter: 619  total_loss: 1.408  loss_cls_stage0: 0.2391  loss_box_reg_stage0: 0.1841  loss_cls_stage1: 0.2184  loss_box_reg_stage1: 0.3112  loss_cls_stage2: 0.1756  loss_box_reg_stage2: 0.3098  loss_rpn_cls: 0.02107  loss_rpn_loc: 0.01205    time: 0.7924  last_time: 0.8507  data_time: 0.0319  last_data_time: 0.0392   lr: 0.001  max_mem: 2436M
# [07/07 02:00:46 d2.utils.events]:  eta: 2:46:28  iter: 639  total_loss: 1.284  loss_cls_stage0: 0.2014  loss_box_reg_stage0: 0.1733  loss_cls_stage1: 0.194  loss_box_reg_stage1: 0.2713  loss_cls_stage2: 0.1483  loss_box_reg_stage2: 0.2427  loss_rpn_cls: 0.02562  loss_rpn_loc: 0.01512    time: 0.7932  last_time: 0.7927  data_time: 0.0246  last_data_time: 0.0155   lr: 0.001  max_mem: 2436M
# [07/07 02:01:03 d2.utils.events]:  eta: 2:46:21  iter: 659  total_loss: 1.355  loss_cls_stage0: 0.213  loss_box_reg_stage0: 0.1616  loss_cls_stage1: 0.2127  loss_box_reg_stage1: 0.3112  loss_cls_stage2: 0.1857  loss_box_reg_stage2: 0.2541  loss_rpn_cls: 0.02375  loss_rpn_loc: 0.01737    time: 0.7941  last_time: 0.8270  data_time: 0.0308  last_data_time: 0.0225   lr: 0.001  max_mem: 2436M
# [07/07 02:01:19 d2.utils.events]:  eta: 2:46:07  iter: 679  total_loss: 1.354  loss_cls_stage0: 0.2045  loss_box_reg_stage0: 0.1624  loss_cls_stage1: 0.2238  loss_box_reg_stage1: 0.2859  loss_cls_stage2: 0.1589  loss_box_reg_stage2: 0.2871  loss_rpn_cls: 0.02164  loss_rpn_loc: 0.009868    time: 0.7948  last_time: 0.8115  data_time: 0.0270  last_data_time: 0.0249   lr: 0.001  max_mem: 2436M
# [07/07 02:01:36 d2.utils.events]:  eta: 2:45:52  iter: 699  total_loss: 1.459  loss_cls_stage0: 0.2164  loss_box_reg_stage0: 0.1672  loss_cls_stage1: 0.2026  loss_box_reg_stage1: 0.2815  loss_cls_stage2: 0.1648  loss_box_reg_stage2: 0.3021  loss_rpn_cls: 0.02378  loss_rpn_loc: 0.02079    time: 0.7958  last_time: 0.8309  data_time: 0.0287  last_data_time: 0.0086   lr: 0.001  max_mem: 2436M
# [07/07 02:01:52 d2.utils.events]:  eta: 2:45:38  iter: 719  total_loss: 1.287  loss_cls_stage0: 0.2037  loss_box_reg_stage0: 0.1786  loss_cls_stage1: 0.1849  loss_box_reg_stage1: 0.3123  loss_cls_stage2: 0.1508  loss_box_reg_stage2: 0.2687  loss_rpn_cls: 0.02016  loss_rpn_loc: 0.01261    time: 0.7966  last_time: 0.8796  data_time: 0.0279  last_data_time: 0.0440   lr: 0.001  max_mem: 2436M
# [07/07 02:02:09 d2.utils.events]:  eta: 2:45:25  iter: 739  total_loss: 1.36  loss_cls_stage0: 0.2116  loss_box_reg_stage0: 0.1866  loss_cls_stage1: 0.1875  loss_box_reg_stage1: 0.311  loss_cls_stage2: 0.1302  loss_box_reg_stage2: 0.2674  loss_rpn_cls: 0.03359  loss_rpn_loc: 0.01434    time: 0.7973  last_time: 0.8185  data_time: 0.0299  last_data_time: 0.0271   lr: 0.001  max_mem: 2436M
# [07/07 02:02:25 d2.utils.events]:  eta: 2:45:14  iter: 759  total_loss: 1.319  loss_cls_stage0: 0.1853  loss_box_reg_stage0: 0.1617  loss_cls_stage1: 0.1925  loss_box_reg_stage1: 0.2764  loss_cls_stage2: 0.1599  loss_box_reg_stage2: 0.2699  loss_rpn_cls: 0.01178  loss_rpn_loc: 0.009973    time: 0.7980  last_time: 0.7862  data_time: 0.0272  last_data_time: 0.0284   lr: 0.001  max_mem: 2436M
# [07/07 02:02:41 d2.utils.events]:  eta: 2:44:59  iter: 779  total_loss: 1.245  loss_cls_stage0: 0.178  loss_box_reg_stage0: 0.1636  loss_cls_stage1: 0.1861  loss_box_reg_stage1: 0.2628  loss_cls_stage2: 0.1553  loss_box_reg_stage2: 0.2578  loss_rpn_cls: 0.01838  loss_rpn_loc: 0.01565    time: 0.7985  last_time: 0.7996  data_time: 0.0255  last_data_time: 0.0094   lr: 0.001  max_mem: 2436M
# [07/07 02:02:58 d2.utils.events]:  eta: 2:44:52  iter: 799  total_loss: 1.205  loss_cls_stage0: 0.1667  loss_box_reg_stage0: 0.142  loss_cls_stage1: 0.1744  loss_box_reg_stage1: 0.2892  loss_cls_stage2: 0.1488  loss_box_reg_stage2: 0.2854  loss_rpn_cls: 0.01224  loss_rpn_loc: 0.01159    time: 0.7992  last_time: 0.8109  data_time: 0.0265  last_data_time: 0.0136   lr: 0.001  max_mem: 2436M
# [07/07 02:03:14 d2.utils.events]:  eta: 2:44:41  iter: 819  total_loss: 1.225  loss_cls_stage0: 0.1606  loss_box_reg_stage0: 0.1402  loss_cls_stage1: 0.1755  loss_box_reg_stage1: 0.2757  loss_cls_stage2: 0.165  loss_box_reg_stage2: 0.3175  loss_rpn_cls: 0.01597  loss_rpn_loc: 0.01285    time: 0.7998  last_time: 0.8711  data_time: 0.0254  last_data_time: 0.0338   lr: 0.001  max_mem: 2436M
# [07/07 02:03:31 d2.utils.events]:  eta: 2:44:26  iter: 839  total_loss: 1.422  loss_cls_stage0: 0.1812  loss_box_reg_stage0: 0.1849  loss_cls_stage1: 0.1802  loss_box_reg_stage1: 0.318  loss_cls_stage2: 0.1644  loss_box_reg_stage2: 0.3281  loss_rpn_cls: 0.01705  loss_rpn_loc: 0.01286    time: 0.8003  last_time: 0.7948  data_time: 0.0237  last_data_time: 0.0090   lr: 0.001  max_mem: 2436M
# [07/07 02:03:47 d2.utils.events]:  eta: 2:44:16  iter: 859  total_loss: 1.388  loss_cls_stage0: 0.1812  loss_box_reg_stage0: 0.1709  loss_cls_stage1: 0.183  loss_box_reg_stage1: 0.2725  loss_cls_stage2: 0.1707  loss_box_reg_stage2: 0.2799  loss_rpn_cls: 0.02353  loss_rpn_loc: 0.01588    time: 0.8010  last_time: 0.8097  data_time: 0.0269  last_data_time: 0.0245   lr: 0.001  max_mem: 2436M
# [07/07 02:04:04 d2.utils.events]:  eta: 2:44:03  iter: 879  total_loss: 1.267  loss_cls_stage0: 0.1819  loss_box_reg_stage0: 0.1826  loss_cls_stage1: 0.1763  loss_box_reg_stage1: 0.3149  loss_cls_stage2: 0.1554  loss_box_reg_stage2: 0.2363  loss_rpn_cls: 0.01952  loss_rpn_loc: 0.01259    time: 0.8015  last_time: 0.8444  data_time: 0.0256  last_data_time: 0.0298   lr: 0.001  max_mem: 2436M
# [07/07 02:04:21 d2.utils.events]:  eta: 2:43:55  iter: 899  total_loss: 1.414  loss_cls_stage0: 0.1872  loss_box_reg_stage0: 0.1807  loss_cls_stage1: 0.192  loss_box_reg_stage1: 0.3469  loss_cls_stage2: 0.1545  loss_box_reg_stage2: 0.2807  loss_rpn_cls: 0.01275  loss_rpn_loc: 0.01105    time: 0.8022  last_time: 0.8328  data_time: 0.0299  last_data_time: 0.0254   lr: 0.001  max_mem: 2436M
# [07/07 02:04:37 d2.utils.events]:  eta: 2:43:40  iter: 919  total_loss: 1.1  loss_cls_stage0: 0.146  loss_box_reg_stage0: 0.1353  loss_cls_stage1: 0.1496  loss_box_reg_stage1: 0.2251  loss_cls_stage2: 0.135  loss_box_reg_stage2: 0.2217  loss_rpn_cls: 0.01301  loss_rpn_loc: 0.01002    time: 0.8028  last_time: 0.8303  data_time: 0.0298  last_data_time: 0.0396   lr: 0.001  max_mem: 2436M
# [07/07 02:04:54 d2.utils.events]:  eta: 2:43:25  iter: 939  total_loss: 1.226  loss_cls_stage0: 0.1526  loss_box_reg_stage0: 0.1645  loss_cls_stage1: 0.156  loss_box_reg_stage1: 0.3231  loss_cls_stage2: 0.1298  loss_box_reg_stage2: 0.2595  loss_rpn_cls: 0.01542  loss_rpn_loc: 0.01294    time: 0.8032  last_time: 0.8527  data_time: 0.0309  last_data_time: 0.0273   lr: 0.001  max_mem: 2436M
# [07/07 02:05:10 d2.utils.events]:  eta: 2:43:16  iter: 959  total_loss: 1.256  loss_cls_stage0: 0.1566  loss_box_reg_stage0: 0.1471  loss_cls_stage1: 0.1719  loss_box_reg_stage1: 0.2824  loss_cls_stage2: 0.1406  loss_box_reg_stage2: 0.2667  loss_rpn_cls: 0.01984  loss_rpn_loc: 0.01217    time: 0.8036  last_time: 0.8443  data_time: 0.0245  last_data_time: 0.0244   lr: 0.001  max_mem: 2436M
# [07/07 02:05:27 d2.utils.events]:  eta: 2:43:04  iter: 979  total_loss: 1.139  loss_cls_stage0: 0.1571  loss_box_reg_stage0: 0.1431  loss_cls_stage1: 0.1686  loss_box_reg_stage1: 0.2693  loss_cls_stage2: 0.1432  loss_box_reg_stage2: 0.3087  loss_rpn_cls: 0.01218  loss_rpn_loc: 0.008968    time: 0.8040  last_time: 0.8285  data_time: 0.0318  last_data_time: 0.0313   lr: 0.001  max_mem: 2436M
# WARNING [07/07 02:05:46 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/07 02:05:46 d2.data.datasets.coco]: Loaded 210 images in COCO format from /content/dataset/valid/_annotations.coco.json
# [07/07 02:05:46 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(640, 640), max_size=640, sample_style='choice')]
# [07/07 02:05:46 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/07 02:05:46 d2.data.common]: Serializing 210 elements to byte tensors and concatenating them all ...
# [07/07 02:05:46 d2.data.common]: Serialized dataset takes 0.07 MiB
# WARNING [07/07 02:05:46 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [07/07 02:05:46 d2.evaluation.evaluator]: Start inference on 210 batches
# [07/07 02:05:47 d2.evaluation.evaluator]: Inference done 11/210. Dataloading: 0.0023 s/iter. Inference: 0.0993 s/iter. Eval: 0.0004 s/iter. Total: 0.1019 s/iter. ETA=0:00:20
# [07/07 02:05:52 d2.evaluation.evaluator]: Inference done 61/210. Dataloading: 0.0016 s/iter. Inference: 0.0983 s/iter. Eval: 0.0003 s/iter. Total: 0.1003 s/iter. ETA=0:00:14
# [07/07 02:05:57 d2.evaluation.evaluator]: Inference done 111/210. Dataloading: 0.0016 s/iter. Inference: 0.0986 s/iter. Eval: 0.0003 s/iter. Total: 0.1006 s/iter. ETA=0:00:09
# [07/07 02:06:02 d2.evaluation.evaluator]: Inference done 156/210. Dataloading: 0.0020 s/iter. Inference: 0.1018 s/iter. Eval: 0.0004 s/iter. Total: 0.1043 s/iter. ETA=0:00:05
# [07/07 02:06:07 d2.evaluation.evaluator]: Inference done 206/210. Dataloading: 0.0019 s/iter. Inference: 0.1011 s/iter. Eval: 0.0003 s/iter. Total: 0.1035 s/iter. ETA=0:00:00
# [07/07 02:06:08 d2.evaluation.evaluator]: Total inference time: 0:00:21.252851 (0.103672 s / iter per device, on 1 devices)
# [07/07 02:06:08 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:20 (0.101075 s / iter per device, on 1 devices)
# [07/07 02:06:08 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/07 02:06:08 d2.evaluation.coco_evaluation]: Saving results to /content/drive/MyDrive/Cascade_RCNN/ResNet50/output/eval/coco_instances_results.json
# [07/07 02:06:08 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# [07/07 02:06:08 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [07/07 02:06:08 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.06 seconds.
# [07/07 02:06:08 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/07 02:06:08 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.03 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.234
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.463
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.209
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.031
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.103
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.283
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.239
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.429
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.446
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.152
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.378
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.498
# [07/07 02:06:08 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 23.437 | 46.348 | 20.948 | 3.146 | 10.334 | 28.293 |
# [07/07 02:06:08 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category    | AP     | category    | AP     | category        | AP    |
# |:------------|:-------|:------------|:-------|:----------------|:------|
# | components  | nan    | Alt Energy  | 14.477 | Circuit Breaker | 8.489 |
# | Control     | 57.328 | Power Lines | 38.368 | Reactor         | 9.196 |
# | Transformer | 12.764 |             |        |                 |       |
# [07/07 02:06:08 d2.engine.defaults]: Evaluation results for substation_valid in csv format:
# [07/07 02:06:08 d2.evaluation.testing]: copypaste: Task: bbox
# [07/07 02:06:08 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [07/07 02:06:08 d2.evaluation.testing]: copypaste: 23.4369,46.3478,20.9475,3.1456,10.3344,28.2932
# [07/07 02:06:08 d2.utils.events]:  eta: 2:42:48  iter: 999  total_loss: 1.212  loss_cls_stage0: 0.1749  loss_box_reg_stage0: 0.158  loss_cls_stage1: 0.165  loss_box_reg_stage1: 0.2856  loss_cls_stage2: 0.132  loss_box_reg_stage2: 0.291  loss_rpn_cls: 0.01647  loss_rpn_loc: 0.01472    time: 0.8044  last_time: 0.8248  data_time: 0.0301  last_data_time: 0.0256   lr: 0.001  max_mem: 2436M
# ...
# WARNING [07/07 05:02:14 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/07 05:02:14 d2.data.datasets.coco]: Loaded 210 images in COCO format from /content/dataset/valid/_annotations.coco.json
# [07/07 05:02:14 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(640, 640), max_size=640, sample_style='choice')]
# [07/07 05:02:14 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/07 05:02:14 d2.data.common]: Serializing 210 elements to byte tensors and concatenating them all ...
# [07/07 05:02:14 d2.data.common]: Serialized dataset takes 0.07 MiB
# WARNING [07/07 05:02:14 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [07/07 05:02:14 d2.evaluation.evaluator]: Start inference on 210 batches
# [07/07 05:02:15 d2.evaluation.evaluator]: Inference done 11/210. Dataloading: 0.0014 s/iter. Inference: 0.0991 s/iter. Eval: 0.0003 s/iter. Total: 0.1008 s/iter. ETA=0:00:20
# [07/07 05:02:20 d2.evaluation.evaluator]: Inference done 57/210. Dataloading: 0.0027 s/iter. Inference: 0.1050 s/iter. Eval: 0.0004 s/iter. Total: 0.1082 s/iter. ETA=0:00:16
# [07/07 05:02:25 d2.evaluation.evaluator]: Inference done 103/210. Dataloading: 0.0025 s/iter. Inference: 0.1058 s/iter. Eval: 0.0005 s/iter. Total: 0.1090 s/iter. ETA=0:00:11
# [07/07 05:02:30 d2.evaluation.evaluator]: Inference done 152/210. Dataloading: 0.0023 s/iter. Inference: 0.1041 s/iter. Eval: 0.0004 s/iter. Total: 0.1069 s/iter. ETA=0:00:06
# [07/07 05:02:35 d2.evaluation.evaluator]: Inference done 199/210. Dataloading: 0.0021 s/iter. Inference: 0.1043 s/iter. Eval: 0.0004 s/iter. Total: 0.1070 s/iter. ETA=0:00:01
# [07/07 05:02:37 d2.evaluation.evaluator]: Total inference time: 0:00:22.020120 (0.107415 s / iter per device, on 1 devices)
# [07/07 05:02:37 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:21 (0.104552 s / iter per device, on 1 devices)
# [07/07 05:02:37 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/07 05:02:37 d2.evaluation.coco_evaluation]: Saving results to /content/drive/MyDrive/Cascade_RCNN/ResNet50/output/eval/coco_instances_results.json
# [07/07 05:02:37 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [07/07 05:02:37 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [07/07 05:02:37 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.04 seconds.
# [07/07 05:02:37 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/07 05:02:37 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.02 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.416
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.676
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.428
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.128
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.358
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.486
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.310
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.487
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.494
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.179
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.441
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.551
# [07/07 05:02:37 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 41.561 | 67.591 | 42.767 | 12.782 | 35.764 | 48.580 |
# [07/07 05:02:37 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category    | AP     | category    | AP     | category        | AP     |
# |:------------|:-------|:------------|:-------|:----------------|:-------|
# | components  | nan    | Alt Energy  | 24.863 | Circuit Breaker | 34.634 |
# | Control     | 62.689 | Power Lines | 54.042 | Reactor         | 26.559 |
# | Transformer | 46.578 |             |        |                 |        |
# [07/07 05:02:37 d2.engine.defaults]: Evaluation results for substation_valid in csv format:
# [07/07 05:02:37 d2.evaluation.testing]: copypaste: Task: bbox
# [07/07 05:02:37 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [07/07 05:02:37 d2.evaluation.testing]: copypaste: 41.5609,67.5912,42.7670,12.7820,35.7637,48.5796
# Training complete.
# Using checkpoint: /content/drive/MyDrive/Cascade_RCNN/ResNet50/output/model_final.pth
# [07/07 05:02:38 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from /content/drive/MyDrive/Cascade_RCNN/ResNet50/output/model_final.pth ...
#
# === Validation Set ===
# WARNING [07/07 05:02:39 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# WARNING [07/07 05:02:39 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/07 05:02:39 d2.data.datasets.coco]: Loaded 210 images in COCO format from /content/dataset/valid/_annotations.coco.json
# [07/07 05:02:39 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(640, 640), max_size=640, sample_style='choice')]
# [07/07 05:02:39 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/07 05:02:39 d2.data.common]: Serializing 210 elements to byte tensors and concatenating them all ...
# [07/07 05:02:39 d2.data.common]: Serialized dataset takes 0.07 MiB
# [07/07 05:02:39 d2.evaluation.evaluator]: Start inference on 210 batches
# [07/07 05:02:41 d2.evaluation.evaluator]: Inference done 14/210. Dataloading: 0.0014 s/iter. Inference: 0.1080 s/iter. Eval: 0.0002 s/iter. Total: 0.1096 s/iter. ETA=0:00:21
# [07/07 05:02:46 d2.evaluation.evaluator]: Inference done 60/210. Dataloading: 0.0016 s/iter. Inference: 0.1082 s/iter. Eval: 0.0002 s/iter. Total: 0.1100 s/iter. ETA=0:00:16
# [07/07 05:02:51 d2.evaluation.evaluator]: Inference done 107/210. Dataloading: 0.0019 s/iter. Inference: 0.1066 s/iter. Eval: 0.0002 s/iter. Total: 0.1087 s/iter. ETA=0:00:11
# [07/07 05:02:56 d2.evaluation.evaluator]: Inference done 155/210. Dataloading: 0.0018 s/iter. Inference: 0.1054 s/iter. Eval: 0.0002 s/iter. Total: 0.1075 s/iter. ETA=0:00:05
# [07/07 05:03:01 d2.evaluation.evaluator]: Inference done 204/210. Dataloading: 0.0018 s/iter. Inference: 0.1046 s/iter. Eval: 0.0002 s/iter. Total: 0.1067 s/iter. ETA=0:00:00
# [07/07 05:03:01 d2.evaluation.evaluator]: Total inference time: 0:00:21.911562 (0.106886 s / iter per device, on 1 devices)
# [07/07 05:03:01 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:21 (0.104455 s / iter per device, on 1 devices)
# [07/07 05:03:02 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/07 05:03:02 d2.evaluation.coco_evaluation]: Saving results to /content/drive/MyDrive/Cascade_RCNN/ResNet50/output/eval_valid/coco_instances_results.json
# [07/07 05:03:02 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [07/07 05:03:02 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [07/07 05:03:02 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.07 seconds.
# [07/07 05:03:02 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/07 05:03:02 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.05 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.397
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.631
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.417
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.119
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.337
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.468
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.455
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.459
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.151
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.393
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.523
# [07/07 05:03:02 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 39.738 | 63.056 | 41.695 | 11.934 | 33.732 | 46.825 |
# [07/07 05:03:02 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category    | AP     | category    | AP     | category        | AP     |
# |:------------|:-------|:------------|:-------|:----------------|:-------|
# | components  | nan    | Alt Energy  | 22.885 | Circuit Breaker | 32.186 |
# | Control     | 61.459 | Power Lines | 52.296 | Reactor         | 25.673 |
# | Transformer | 43.929 |             |        |                 |        |
# OrderedDict({'bbox': {'AP': 39.73817091967808, 'AP50': 63.055977790825004, 'AP75': 41.695051460456746, 'APs': 11.933537657727648, 'APm': 33.73156817023764, 'APl': 46.825003282732446, 'AP-components': nan, 'AP-Alt Energy': 22.884888593110226, 'AP-Circuit Breaker': 32.186479483579866, 'AP-Control': 61.45890879701381, 'AP-Power Lines': 52.296488696066575, 'AP-Reactor': 25.672918730791228, 'AP-Transformer': 43.92934121750676}})
#
# === Test Set ===
# WARNING [07/07 05:03:02 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# WARNING [07/07 05:03:02 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/07 05:03:02 d2.data.datasets.coco]: Loaded 137 images in COCO format from /content/dataset/test/_annotations.coco.json
# [07/07 05:03:02 d2.data.build]: Distribution of instances among all 7 categories:
# |  category   | #instances   |  category   | #instances   |   category    | #instances   |
# |:-----------:|:-------------|:-----------:|:-------------|:-------------:|:-------------|
# | components  | 0            | Alt Energy  | 54           | Circuit Bre.. | 153          |
# |   Control   | 19           | Power Lines | 32           |    Reactor    | 58           |
# | Transformer | 61           |             |              |               |              |
# |    total    | 377          |             |              |               |              |
# [07/07 05:03:02 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(640, 640), max_size=640, sample_style='choice')]
# [07/07 05:03:02 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/07 05:03:02 d2.data.common]: Serializing 137 elements to byte tensors and concatenating them all ...
# [07/07 05:03:02 d2.data.common]: Serialized dataset takes 0.04 MiB
# [07/07 05:03:02 d2.evaluation.evaluator]: Start inference on 137 batches
# [07/07 05:03:06 d2.evaluation.evaluator]: Inference done 38/137. Dataloading: 0.0017 s/iter. Inference: 0.0995 s/iter. Eval: 0.0002 s/iter. Total: 0.1014 s/iter. ETA=0:00:10
# [07/07 05:03:11 d2.evaluation.evaluator]: Inference done 88/137. Dataloading: 0.0016 s/iter. Inference: 0.0988 s/iter. Eval: 0.0002 s/iter. Total: 0.1007 s/iter. ETA=0:00:04
# [07/07 05:03:16 d2.evaluation.evaluator]: Total inference time: 0:00:13.320697 (0.100914 s / iter per device, on 1 devices)
# [07/07 05:03:16 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:12 (0.098350 s / iter per device, on 1 devices)
# [07/07 05:03:16 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/07 05:03:16 d2.evaluation.coco_evaluation]: Saving results to /content/drive/MyDrive/Cascade_RCNN/ResNet50/output/eval_test/coco_instances_results.json
# [07/07 05:03:16 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [07/07 05:03:16 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [07/07 05:03:16 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.04 seconds.
# [07/07 05:03:16 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/07 05:03:16 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.04 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.284
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.464
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.320
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.076
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.130
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.348
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.264
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.342
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.351
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.215
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.399
# [07/07 05:03:16 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 28.366 | 46.368 | 31.975 | 7.600 | 12.975 | 34.824 |
# [07/07 05:03:16 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category    | AP     | category    | AP     | category        | AP     |
# |:------------|:-------|:------------|:-------|:----------------|:-------|
# | components  | nan    | Alt Energy  | 20.853 | Circuit Breaker | 12.487 |
# | Control     | 55.086 | Power Lines | 54.349 | Reactor         | 11.615 |
# | Transformer | 15.806 |             |        |                 |        |
# OrderedDict({'bbox': {'AP': 28.365959143826945, 'AP50': 46.36750259120127, 'AP75': 31.974505976194713, 'APs': 7.599951373043555, 'APm': 12.974559684607714, 'APl': 34.823552214856086, 'AP-components': nan, 'AP-Alt Energy': 20.852803720312576, 'AP-Circuit Breaker': 12.486596617975602, 'AP-Control': 55.08555319817696, 'AP-Power Lines': 54.34938086836346, 'AP-Reactor': 11.61533307083028, 'AP-Transformer': 15.806087387302819}})
#
# =================================================================
#   FINAL RESULTS — Cascade R-CNN ResNet-50 FPN
# =================================================================
#
# (a) Overall Performance (mAP@50):
#     Validation : 63.06
#     Test       : 46.37
#
# (b) Overall Performance (mAP@50:95):
#     Validation : 39.74
#     Test       : 28.37
#
# (c) Alt Energy (AP test): 20.85
# (d) Circuit Breaker (AP test): 12.49
# (e) Control (AP test): 55.09
# (f) Power Lines (AP test): 54.35
# (g) Reactor (AP test): 11.62
# (h) Transformer (AP test): 15.81
# =================================================================
#
# CSV saved to: /content/drive/MyDrive/Cascade_RCNN/ResNet50/results_for_charts.csv
# Checkpoint saved at: /content/drive/MyDrive/Cascade_RCNN/ResNet50/output/model_final.pth
# Everything saved directly to Google Drive.
